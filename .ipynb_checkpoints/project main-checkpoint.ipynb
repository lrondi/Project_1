# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import log2
from scipy.stats import chi2_contingency
import seaborn as sns
import numpy as np
import scipy.stats as stats

# %%
# Load data for RNAseq TPM:
# Cvs has 40 columns, comprising 4 replicates of each sample

data = pd.read_csv('rnaSeqTPM.tsv',delimiter='\t')
data.head()
# Out:
#         target  AC-10_L001-ds.a84fdb211ec34671aca066ec644cf980  \
# 0  14266|CENPU                                         26.5465
# 1  13331|PEX14                                         14.7797
# 2   6630|RAD52                                         10.6624
# 3  16802|CLYBL                                         14.9415
# 4  6645|RANBP1                                        120.0090
#
#    AC-10_L002-ds.2ddd07759d0049598e038c6f5ba208fa  \
# 0                                         16.2036
# 1                                         30.2357
# 2                                         11.1358
# 3                                         15.5777
# 4                                         95.8606
#
#    AC-10_L003-ds.c54fbdfec6c64f5f9b34d857bdc2d39b  \
# 0                                        15.82680
# 1                                        14.57500
# 2                                        14.51280
# 3                                         5.08468
# 4                                       115.83400
#
#    AC-10_L004-ds.2bd4291178074656a4052e86fe3a627e  \
# 0                                        23.04800
# 1                                        20.07720
# 2                                        11.07570
# 3                                         6.89438
# 4                                        81.36820
#
#    AC-1_L001-ds.4e1b9a9de76b4859a777b1e85ee85940  \
# 0                                        4.27284
# 1                                       25.98820
# 2                                       10.32110
# 3                                       19.27520
# 4                                       65.89110
#
#    AC-1_L002-ds.01aba20a131d47c1ab69483d8ec077ec  \
# 0                                        4.34290
# 1                                       53.11600
# 2                                        7.00181
# 3                                        3.27223
# 4                                       52.77280
#
#    AC-1_L003-ds.88a026919bd04bc5a4216cb9f1c13b9f  \
# 0                                        0.00000
# 1                                       34.81970
# 2                                        6.95342
# 3                                        6.50129
# 4                                       55.74450
#
#    AC-1_L004-ds.7f15d836c940438a91be474a714f4b2c  \
# 0                                         0.0000
# 1                                        35.4412
# 2                                        17.4680
# 3                                        16.3063
# 4                                        89.2274
#
#    AC-2_L001-ds.857a9a7bb18646108f52f84bc5b08aaf  \
# 0                                       49.09530
# 1                                       20.75710
# 2                                       25.68350
# 3                                        2.67345
# 4                                      436.34000
#
#                        ...                        \
# 0                      ...
# 1                      ...
# 2                      ...
# 3                      ...
# 4                      ...
#
#    AC-7_L003-ds.90fc01aaf24b45caa6e05a27f56c79a1  \
# 0                                        3.85098
# 1                                       23.94680
# 2                                        9.45641
# 3                                        0.00000
# 4                                      124.60800
#
#    AC-7_L004-ds.422324df17bb4355a209d2e206d4ebc0  \
# 0                                        0.00000
# 1                                       24.49580
# 2                                        6.51098
# 3                                       12.25740
# 4                                       83.27780
#
#    AC-8_L001-ds.b12e8f44abb04463b2f39d8752f94941  \
# 0                                       80.97500
# 1                                        9.05497
# 2                                        3.51170
# 3                                       16.36970
# 4                                      142.70700
#
#    AC-8_L002-ds.a0c59a8dc0f24e30aec2c8d0a17334ca  \
# 0                                       61.55940
# 1                                       13.72040
# 2                                        3.51882
# 3                                       14.76480
# 4                                      171.49800
#
#    AC-8_L003-ds.e77040b8045f45478d3aeef2c419abb9  \
# 0                                       50.31760
# 1                                       41.40420
# 2                                        8.84862
# 3                                       14.85800
# 4                                      198.41100
#
#    AC-8_L004-ds.04e2a2a871c145e49fb29ada5cf53c09  \
# 0                                       65.41160
# 1                                       27.30500
# 2                                        3.60949
# 3                                        6.74993
# 4                                      171.52600
#
#    AC-9_L001-ds.a46dbd8c24a44ddea892e43e28a4ba93  \
# 0                                        2.26704
# 1                                       18.80870
# 2                                        9.13044
# 3                                       11.92510
# 4                                       86.65530
#
#    AC-9_L002-ds.bbb091f5bbca4f889ad07186bc5d1f49  \
# 0                                        2.31271
# 1                                       37.86440
# 2                                       14.82380
# 3                                        5.18773
# 4                                      105.10300
#
#    AC-9_L003-ds.194a0d6a4ab447dab95363ede97522f3  \
# 0                                       18.11890
# 1                                       14.20190
# 2                                        7.27973
# 3                                        8.49613
# 4                                       47.65850
#
#    AC-9_L004-ds.9eb4326b03f84467a6b399d8f09fd9da
# 0                                        6.95662
# 1                                       14.27680
# 2                                       16.71440
# 3                                        3.46830
# 4                                       64.37860
#
# [5 rows x 41 columns]

# %%
# Rename columns

data = data.rename(columns={'AC-10_L001-ds.a84fdb211ec34671aca066ec644cf980':'AC10_1',
       'AC-10_L002-ds.2ddd07759d0049598e038c6f5ba208fa':'AC10_2','AC-10_L003-ds.c54fbdfec6c64f5f9b34d857bdc2d39b':'AC10_3',
       'AC-10_L004-ds.2bd4291178074656a4052e86fe3a627e':'AC10_4','AC-1_L001-ds.4e1b9a9de76b4859a777b1e85ee85940':'AC1_1',
       'AC-1_L002-ds.01aba20a131d47c1ab69483d8ec077ec':'AC1_2','AC-1_L003-ds.88a026919bd04bc5a4216cb9f1c13b9f':'AC1_3',
       'AC-1_L004-ds.7f15d836c940438a91be474a714f4b2c':'AC1_4','AC-2_L001-ds.857a9a7bb18646108f52f84bc5b08aaf':'AC2_1',
       'AC-2_L002-ds.5a9da74220064ee89a9736bc85a52179':'AC2_2','AC-2_L003-ds.e6194500d53a4f33bfc7915c64a5beeb':'AC2_3',
       'AC-2_L004-ds.246b173490c3494a8eeea8621ec361d1':'AC2_4','AC-3_L001-ds.58010ec40df84a978e4af7d1a23d1af9':'AC3_1',
       'AC-3_L002-ds.454403b9d0ac4d72af1220546b5a630d':'AC3_2','AC-3_L003-ds.d83a7a6dd4c545b1b2170c1100cf2120':'AC3_3',
       'AC-3_L004-ds.6cf9ff6076264856a74212cfc7410e96':'AC3_4','AC-4_L001-ds.e45254993f044e7da3deb87a28e560a4':'AC4_1',
       'AC-4_L002-ds.fcf9658251c14b40b7ed788a6f9d1adb':'AC4_2','AC-4_L003-ds.109477542e734e6c8c93bedd405a3039':'AC4_3',
       'AC-4_L004-ds.d101269468414b71a926cd9fc76cb004':'AC4_4','AC-5_L001-ds.bd13708d4f784119ac0a2ae972e37f66':'AC5_1',
       'AC-5_L002-ds.ffd221b8bc164be3b6d604985219be02':'AC5_2','AC-5_L003-ds.8d1b59e10e7b4ae7bd089b99744e3802':'AC5_3',
       'AC-5_L004-ds.9b5362075da148408cb715587ce595a5':'AC5_4','AC-6_L001-ds.3ab380d9704849cda96aed57e96e6586':'AC6_1',
       'AC-6_L002-ds.6d19015742374d079236d90ae72f1d2a':'AC6_2','AC-6_L003-ds.f4a789852ddb477bad1ab00670699315':'AC6_3',
       'AC-6_L004-ds.a5e6028617944efd9b68ef878d9df54e':'AC6_4','AC-7_L001-ds.fc6c5f45845543248f39571f54a4fa7b':'AC7_1',
       'AC-7_L002-ds.9da13968f23c45489f6bcee732149847':'AC7_2','AC-7_L003-ds.90fc01aaf24b45caa6e05a27f56c79a1':'AC7_3',
       'AC-7_L004-ds.422324df17bb4355a209d2e206d4ebc0':'AC7_4','AC-8_L001-ds.b12e8f44abb04463b2f39d8752f94941':'AC8_1',
       'AC-8_L002-ds.a0c59a8dc0f24e30aec2c8d0a17334ca':'AC8_2','AC-8_L003-ds.e77040b8045f45478d3aeef2c419abb9':'AC8_3',
       'AC-8_L004-ds.04e2a2a871c145e49fb29ada5cf53c09':'AC8_4','AC-9_L001-ds.a46dbd8c24a44ddea892e43e28a4ba93':'AC9_1',
       'AC-9_L002-ds.bbb091f5bbca4f889ad07186bc5d1f49':'AC9_2','AC-9_L003-ds.194a0d6a4ab447dab95363ede97522f3':'AC9_3',
       'AC-9_L004-ds.9eb4326b03f84467a6b399d8f09fd9da':'AC9_4'})
data.head()
# Out:
#         target    AC10_1   AC10_2     AC10_3    AC10_4     AC1_1     AC1_2  \
# 0  14266|CENPU   26.5465  16.2036   15.82680  23.04800   4.27284   4.34290
# 1  13331|PEX14   14.7797  30.2357   14.57500  20.07720  25.98820  53.11600
# 2   6630|RAD52   10.6624  11.1358   14.51280  11.07570  10.32110   7.00181
# 3  16802|CLYBL   14.9415  15.5777    5.08468   6.89438  19.27520   3.27223
# 4  6645|RANBP1  120.0090  95.8606  115.83400  81.36820  65.89110  52.77280
#
#       AC1_3    AC1_4      AC2_1    ...         AC7_3     AC7_4      AC8_1  \
# 0   0.00000   0.0000   49.09530    ...       3.85098   0.00000   80.97500
# 1  34.81970  35.4412   20.75710    ...      23.94680  24.49580    9.05497
# 2   6.95342  17.4680   25.68350    ...       9.45641   6.51098    3.51170
# 3   6.50129  16.3063    2.67345    ...       0.00000  12.25740   16.36970
# 4  55.74450  89.2274  436.34000    ...     124.60800  83.27780  142.70700
#
#        AC8_2      AC8_3      AC8_4     AC9_1      AC9_2     AC9_3     AC9_4
# 0   61.55940   50.31760   65.41160   2.26704    2.31271  18.11890   6.95662
# 1   13.72040   41.40420   27.30500  18.80870   37.86440  14.20190  14.27680
# 2    3.51882    8.84862    3.60949   9.13044   14.82380   7.27973  16.71440
# 3   14.76480   14.85800    6.74993  11.92510    5.18773   8.49613   3.46830
# 4  171.49800  198.41100  171.52600  86.65530  105.10300  47.65850  64.37860
#
# [5 rows x 41 columns]

# %%
# Take mean every four replicates of each sample, add as new column and rename columns as appropiate

n = 1
m = 5
p = 1
for _ in range(10):
    
    data[f'AC{p}'] = data.iloc[:,n:m].mean(axis=1)
    p = p+1
    n = n+4
    m = m+4

data = data.rename(columns ={'AC1':'AC10','AC2':'AC1','AC3':'AC2','AC4':'AC3','AC5':'AC4','AC6':'AC5','AC7':'AC6',
                             'AC8':'AC7','AC9':'AC8','AC10':'AC9'})
data.head()
# Out:
#         target    AC10_1   AC10_2     AC10_3    AC10_4     AC1_1     AC1_2  \
# 0  14266|CENPU   26.5465  16.2036   15.82680  23.04800   4.27284   4.34290
# 1  13331|PEX14   14.7797  30.2357   14.57500  20.07720  25.98820  53.11600
# 2   6630|RAD52   10.6624  11.1358   14.51280  11.07570  10.32110   7.00181
# 3  16802|CLYBL   14.9415  15.5777    5.08468   6.89438  19.27520   3.27223
# 4  6645|RANBP1  120.0090  95.8606  115.83400  81.36820  65.89110  52.77280
#
#       AC1_3    AC1_4      AC2_1    ...            AC10        AC1         AC2  \
# 0   0.00000   0.0000   49.09530    ...       20.406225   2.153935   42.743575
# 1  34.81970  35.4412   20.75710    ...       19.916900  37.341275   15.845198
# 2   6.95342  17.4680   25.68350    ...       11.846675  10.436083   21.691725
# 3   6.50129  16.3063    2.67345    ...       10.624565  11.338755    8.822482
# 4  55.74450  89.2274  436.34000    ...      103.267950  65.908950  346.465250
#
#           AC3         AC4        AC5         AC6        AC7         AC8  \
# 0   51.583525   18.622583   3.504800   58.203800   1.938013   64.565900
# 1   15.942073   51.209025  17.724160   23.905800  20.258400   22.871142
# 2   13.252975    7.072937   5.070735    7.610290  11.173897    4.872158
# 3    4.750612   20.617875  26.773325    9.021778   4.565878   13.185607
# 4  226.077000  127.275900  48.031900  102.964925  89.185500  171.035500
#
#          AC9
# 0   7.413818
# 1  21.287950
# 2  11.987092
# 3   7.269315
# 4  75.948850
#
# [5 rows x 51 columns]

# %%
# Rename columns with samples names

data_rnas = data[['target','AC1','AC2','AC3','AC4','AC5','AC6','AC7','AC8','AC9','AC10']]
data_rnas = data_rnas.rename(columns ={'target':'target gene','AC1':'Brain','AC2':'Univ Stratagene','AC3':'Univ DriverMap',
                             'AC4':'Univ Clontech','AC5':'Univ BioChain','AC6':'Univ Rare','AC7':'WB-Activated',
                             'AC8':'WB-Disease','AC9':'Univ ImmuneT10','AC10':'Hemat System3'})
data_rnas = data_rnas.set_index('target gene')
data_rnas.head()
# Out:
#                  Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# target gene
# 14266|CENPU   2.153935        42.743575       51.583525      18.622583
# 13331|PEX14  37.341275        15.845198       15.942073      51.209025
# 6630|RAD52   10.436083        21.691725       13.252975       7.072937
# 16802|CLYBL  11.338755         8.822482        4.750612      20.617875
# 6645|RANBP1  65.908950       346.465250      226.077000     127.275900
#
#              Univ BioChain   Univ Rare  WB-Activated  WB-Disease  \
# target gene
# 14266|CENPU       3.504800   58.203800      1.938013   64.565900
# 13331|PEX14      17.724160   23.905800     20.258400   22.871142
# 6630|RAD52        5.070735    7.610290     11.173897    4.872158
# 16802|CLYBL      26.773325    9.021778      4.565878   13.185607
# 6645|RANBP1      48.031900  102.964925     89.185500  171.035500
#
#              Univ ImmuneT10  Hemat System3
# target gene
# 14266|CENPU        7.413818      20.406225
# 13331|PEX14       21.287950      19.916900
# 6630|RAD52        11.987092      11.846675
# 16802|CLYBL        7.269315      10.624565
# 6645|RANBP1       75.948850     103.267950

# %%
# Function that takes log of values in column and adds new column to df with logs

def log_df(df):
    columns_list = df.columns
    for column in columns_list:
        # Make new column name
        col_name = column+'_log'
        # Make list with values of rows in original column
        col_numbers = list(df[column])
        # Take logs and store in new array
        log_numbers = []
        for num in col_numbers:
            if num > 1:
                log_numbers.append(log2(num))
            else:
                log_numbers.append(0) # a TPM of 1 or less means 0 fold change
        # Make new column in original df with log array
        df[col_name] = log_numbers
    return

# %%
# Aplly log function to df and make new df of only logs

# First make copy of df so we don't modify it and apply log function
data_rnas2 = data_rnas
log_df(data_rnas2)

#Second, make df with only logs
data_rnas_log = data_rnas2.iloc[:,10:20]
data_rnas_log.head()
# Out:
#              Brain_log  Univ Stratagene_log  Univ DriverMap_log  \
# target gene
# 14266|CENPU   1.106975             5.417636            5.688838
# 13331|PEX14   5.222699             3.985974            3.994767
# 6630|RAD52    3.383508             4.439073            3.728244
# 16802|CLYBL   3.503190             3.141185            2.248114
# 6645|RANBP1   6.042402             8.436567            7.820670
#
#              Univ Clontech_log  Univ BioChain_log  Univ Rare_log  \
# target gene
# 14266|CENPU           4.218981           1.809332       5.863041
# 13331|PEX14           5.678326           4.147645       4.579289
# 6630|RAD52            2.822310           2.342195       2.927951
# 16802|CLYBL           4.365824           4.742724       3.173412
# 6645|RANBP1           6.991815           5.585921       6.686009
#
#              WB-Activated_log  WB-Disease_log  Univ ImmuneT10_log  \
# target gene
# 14266|CENPU          0.954578        6.012701            2.890217
# 13331|PEX14          4.340448        4.515457            4.411965
# 6630|RAD52           3.482061        2.284561            3.583410
# 16802|CLYBL          2.190892        3.720892            2.861819
# 6645|RANBP1          6.478737        7.418152            6.246956
#
#              Hemat System3_log
# target gene
# 14266|CENPU           4.350937
# 13331|PEX14           4.315921
# 6630|RAD52            3.566410
# 16802|CLYBL           3.409332
# 6645|RANBP1           6.690249

# %%
# Making transpose df to do heatmap more efficient

tab_rnas = data_rnas_log.transpose()
tab_rnas.head()
# Out:
# target gene          14266|CENPU  13331|PEX14  6630|RAD52  16802|CLYBL  \
# Brain_log               1.106975     5.222699    3.383508     3.503190
# Univ Stratagene_log     5.417636     3.985974    4.439073     3.141185
# Univ DriverMap_log      5.688838     3.994767    3.728244     2.248114
# Univ Clontech_log       4.218981     5.678326    2.822310     4.365824
# Univ BioChain_log       1.809332     4.147645    2.342195     4.742724
#
# target gene          6645|RANBP1  12149|KDF1  11733|TBC1D30  14535|TMEM258  \
# Brain_log               6.042402    2.245839       5.061035       6.693610
# Univ Stratagene_log     8.436567    2.963911       2.822148       8.210013
# Univ DriverMap_log      7.820670    4.729278       3.648200       7.627450
# Univ Clontech_log       6.991815    1.497970       3.318626       6.803169
# Univ BioChain_log       5.585921    1.712148       0.695954       6.224163
#
# target gene          12400|LRG1  11931|HYAL1     ...      16176|GAB3  \
# Brain_log              0.000000     4.054180     ...        0.000000
# Univ Stratagene_log    4.251886     3.756653     ...        0.685171
# Univ DriverMap_log     3.118327     0.785576     ...        0.000000
# Univ Clontech_log      3.478247     5.185426     ...        2.567949
# Univ BioChain_log      7.465277     6.353782     ...        0.000000
#
# target gene          13299|ZNF701  5706|NEB  15110|ZNF775  3181|CCNB2  \
# Brain_log                2.075561  0.337782      5.139967    0.000000
# Univ Stratagene_log      1.289013  0.064607      3.983449    6.592308
# Univ DriverMap_log       2.836249  1.458984      3.313137    6.048997
# Univ Clontech_log        1.039789  1.540372      4.355929    4.513309
# Univ BioChain_log        2.461696  0.000000      1.378955    1.755232
#
# target gene          16735|BBS12  14784|ANKRD27  3464|COL19A1  10238|TCTA  \
# Brain_log               2.449345       4.636225      3.332654    4.913491
# Univ Stratagene_log     0.000000       4.254808      0.000000    3.761934
# Univ DriverMap_log      0.793720       5.592719      0.000000    4.562096
# Univ Clontech_log       2.231803       5.537454      0.849012    4.562743
# Univ BioChain_log       0.178158       3.819152      0.000000    4.572714
#
# target gene          10545|CA5A
# Brain_log              0.000000
# Univ Stratagene_log    0.000000
# Univ DriverMap_log     0.000000
# Univ Clontech_log      0.000000
# Univ BioChain_log      4.058026
#
# [5 rows x 18989 columns]

# %%
# Load data for DriverMap (DM) from csv
# Csv has 20 columns, comprising 10 same samples and 2 different treatments

data_dm2 = pd.read_csv('DriverMapTPM.tsv',delimiter='\t')
data_dm2 = data_dm2.rename(columns={'Unnamed: 0':'target gene'})
data_dm2 = data_dm2.set_index('target gene')
data_dm2.head()
# Out:
#                   A10       A11     A12         A2         A3         A4  \
# target gene
# 14266|CENPU  17.60490  23.53280   0.000   0.294876   43.10860   70.50920
# 13331|PEX14  19.08750  14.08670   0.000  27.671900   25.00070   17.33890
# 6630|RAD52    3.66106   4.29017   0.000   5.274080    6.98958    3.28098
# 16802|CLYBL  11.47500  12.58540  34.475  16.894700   14.28180    4.92852
# 6645|RANBP1  71.64050  79.22280   0.000  45.997900  218.58800  143.56100
#
#                    A5        A6        A7        A8    ...          B11  \
# target gene                                            ...
# 14266|CENPU  21.41510   1.14305  47.16210   1.43697    ...     20.49390
# 13331|PEX14  25.84810  12.43200  18.08010  10.52050    ...     17.62190
# 6630|RAD52    4.90895   1.53928   5.35737   1.73986    ...      6.29135
# 16802|CLYBL  30.36700  28.94250  15.52040   7.25044    ...      9.44277
# 6645|RANBP1  82.09650  30.95460  70.32010  51.50090    ...     66.10810
#
#                   B12         B2        B3        B4        B5        B6  \
# target gene
# 14266|CENPU   0.00000   0.546198   48.0853  74.59220  26.27370   1.19616
# 13331|PEX14   0.00000  33.521000   26.2342  24.65790  36.15540  15.84860
# 6630|RAD52    3.60232   7.170180   10.8381   6.08676   6.61974   3.46454
# 16802|CLYBL  38.90040  11.170000   12.2971   4.87524  24.46830  21.38690
# 6645|RANBP1   7.38547  35.480200  105.3570  93.05350  46.65610  24.73280
#
#                    B7        B8        B9
# target gene
# 14266|CENPU  45.71820   2.83643  122.2470
# 13331|PEX14  18.20870  14.82460   34.4379
# 6630|RAD52    7.99667   2.27730    8.2883
# 16802|CLYBL  12.00770   3.81662   16.9272
# 6645|RANBP1  47.38680  41.90630  118.2290
#
# [5 rows x 22 columns]

# %%
# Make new df with only first treatment, rearrange columns and rename them with sample's names

data_dm = data_dm2.iloc[:,0:11]
data_dm = data_dm[['A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11']]
data_dm.columns = ['Brain', 'Univ Stratagene', 'Univ DriverMap','Univ Clontech', 'Univ BioChain','Univ Rare',
                'WB-Activated','WB-Disease', 'Univ ImmuneT10', 'Hemat System3']
data_dm.head()
# Out:
#                  Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# target gene
# 14266|CENPU   0.294876         43.10860        70.50920       21.41510
# 13331|PEX14  27.671900         25.00070        17.33890       25.84810
# 6630|RAD52    5.274080          6.98958         3.28098        4.90895
# 16802|CLYBL  16.894700         14.28180         4.92852       30.36700
# 6645|RANBP1  45.997900        218.58800       143.56100       82.09650
#
#              Univ BioChain  Univ Rare  WB-Activated  WB-Disease  \
# target gene
# 14266|CENPU        1.14305   47.16210       1.43697    96.96370
# 13331|PEX14       12.43200   18.08010      10.52050    29.29620
# 6630|RAD52         1.53928    5.35737       1.73986     4.92102
# 16802|CLYBL       28.94250   15.52040       7.25044    18.39990
# 6645|RANBP1       30.95460   70.32010      51.50090   134.60400
#
#              Univ ImmuneT10  Hemat System3
# target gene
# 14266|CENPU        17.60490       23.53280
# 13331|PEX14        19.08750       14.08670
# 6630|RAD52          3.66106        4.29017
# 16802|CLYBL        11.47500       12.58540
# 6645|RANBP1        71.64050       79.22280

# %%
# Aplly log function to df and make new df of only logs

# First make copy of df so we don't modify it and apply log function
data_dm_b = data_dm
log_df(data_dm_b)

# Second, make df with only logs, rename columns so they're different from the RNAseq log df
data_dm_log = data_dm_b.iloc[:,10:20]
data_dm_log.columns = ['Brain', 'Univ Stratagene', 'Univ DriverMap','Univ Clontech', 'Univ BioChain','Univ Rare',
                'WB-Activated','WB-Disease', 'Univ ImmuneT10', 'Hemat System3']
data_dm_log.head()
# Out:
#                 Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# target gene
# 14266|CENPU  0.000000         5.429904        6.139740       4.420557
# 13331|PEX14  4.790350         4.643897        4.115940       4.691986
# 6630|RAD52   2.398919         2.805206        1.714127       2.295414
# 16802|CLYBL  4.078499         3.836106        2.301154       4.924432
# 6645|RANBP1  5.523496         7.772070        7.165520       6.359249
#
#              Univ BioChain  Univ Rare  WB-Activated  WB-Disease  \
# target gene
# 14266|CENPU       0.192889   5.559556      0.523030    6.599373
# 13331|PEX14       3.635987   4.176331      3.395131    4.872642
# 6630|RAD52        0.622256   2.421525      0.798971    2.298957
# 16802|CLYBL       4.855118   3.956094      2.858069    4.201626
# 6645|RANBP1       4.952082   6.135865      5.686526    7.072577
#
#              Univ ImmuneT10  Hemat System3
# target gene
# 14266|CENPU        4.137905       4.556601
# 13331|PEX14        4.254556       3.816262
# 6630|RAD52         1.872261       2.101035
# 16802|CLYBL        3.520422       3.653679
# 6645|RANBP1        6.162704       6.307844

# %%
# Making transpose df to do heatmap more efficient

tab_dm = data_dm_log.transpose()
tab_dm.head()
# Out:
# target gene      14266|CENPU  13331|PEX14  6630|RAD52  16802|CLYBL  \
# Brain               0.000000     4.790350    2.398919     4.078499
# Univ Stratagene     5.429904     4.643897    2.805206     3.836106
# Univ DriverMap      6.139740     4.115940    1.714127     2.301154
# Univ Clontech       4.420557     4.691986    2.295414     4.924432
# Univ BioChain       0.192889     3.635987    0.622256     4.855118
#
# target gene      6645|RANBP1  12149|KDF1  11733|TBC1D30  14535|TMEM258  \
# Brain               5.523496    1.228763       4.103053       6.710173
# Univ Stratagene     7.772070    1.961342       2.042179       8.095830
# Univ DriverMap      7.165520    3.665779       3.331720       7.717162
# Univ Clontech       6.359249    2.496324       2.617870       6.586897
# Univ BioChain       4.952082    1.895225       0.000000       5.822544
#
# target gene      12400|LRG1  11931|HYAL1     ...      16176|GAB3  \
# Brain              0.000000     1.276145     ...        0.306146
# Univ Stratagene    2.952479     3.981332     ...        1.133307
# Univ DriverMap     2.640952     0.699054     ...        0.000000
# Univ Clontech      2.452421     4.728546     ...        2.585083
# Univ BioChain      6.381131     6.184342     ...        0.996779
#
# target gene      13299|ZNF701  5706|NEB  15110|ZNF775  3181|CCNB2  \
# Brain                1.214970  0.332553      3.694891    0.000000
# Univ Stratagene      1.688910  0.000000      3.407176    3.999648
# Univ DriverMap       2.022876  0.497485      1.224682    3.687833
# Univ Clontech        0.755546  0.000000      3.172569    2.424041
# Univ BioChain        0.895566  0.289598      0.508003    0.000000
#
# target gene      16735|BBS12  14784|ANKRD27  3464|COL19A1  10238|TCTA  \
# Brain               2.398799       5.263639      1.572458    4.136503
# Univ Stratagene     0.966903       5.717493      0.000000    3.399294
# Univ DriverMap      1.068299       5.943832      0.000000    3.814048
# Univ Clontech       1.751399       5.473982      0.000000    4.217626
# Univ BioChain       0.000000       3.774924      0.000000    3.042280
#
# target gene      10545|CA5A
# Brain              0.000000
# Univ Stratagene    0.560686
# Univ DriverMap     0.000000
# Univ Clontech      0.000000
# Univ BioChain      3.868736
#
# [5 rows x 18989 columns]

# %% [markdown]
# # Braod analysis of whole transcriptome sequencing differences between techniques

# %%
# First glimpse at difference between techniques: heatmap for logs of each gene, sample and technique

plt.figure(figsize = (20,4))
labels = list(data_dm_log.columns)
sns.heatmap(tab_rnas, xticklabels = False, yticklabels = labels, cbar_kws = {'label':'log(TPM)'})
plt.title('Heatmap for RNAseq')

plt.figure(figsize = (20,4))
sns.heatmap(tab_dm, xticklabels = False, yticklabels = labels, cbar_kws = {'label':'log(TPM)'})
plt.title('Heatmap for DM')
# Out:
# Text(0.5, 1.0, 'Heatmap for DM')

# %%
# Making heatmap for just 5 genes, to see how it looks

mini_rnas_log = data_rnas_log.head()
mini_rnas_log = mini_rnas_log.transpose()
mini_dm_log = data_dm_log.head()
mini_dm_log = mini_dm_log.transpose()

plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
sns.heatmap(mini_rnas_log, yticklabels = labels) 
plt.subplot(1,2,2)
sns.heatmap(mini_dm_log, yticklabels = False, cbar_kws = {'label':'log(read count)'})
plt.tight_layout()

# %%
# To further evaluate if techniques are comparable, we do scatter plots of log(RNAseq) vs log(DM) for each sample,
# because samples are independent

fig, ax = plt.subplots(2,5,figsize=(20,10))
n=0
for i in range(2):
    for j in range(5):
        ax[i,j].scatter(x = data_rnas_log.iloc[:,n], y = data_dm_log.iloc[:,n], s = 5)
        ax[i,j].set_title(labels[n], fontsize = 15)
        n=n+1

plt.tight_layout()

# %%
# Because scatter plot doesn't let you see density of points, and to smooth the dispersion, we do a 
# Kernel-Density Estimate plot (KDE)

sns.jointplot(x=data_rnas_log['Brain_log'],y=data_dm_log['Brain'],color='skyblue',kind='kde')
# Out:
# C:\Users\luron\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# One-way ANOVA analysis of techniques for each sample

brain_rnas = data_rnas_log['Brain_log']
brain_dm = data_dm_log['Brain']

strata_rnas = data_rnas_log['Univ Stratagene_log']
strata_dm = data_dm_log['Univ Stratagene']

driver_rnas = data_rnas_log['Univ DriverMap_log']
driver_dm = data_dm_log['Univ DriverMap']

clon_rnas = data_rnas_log['Univ Clontech_log']
clon_dm = data_dm_log['Univ Clontech']

bioch_rnas = data_rnas_log['Univ BioChain_log']
bioch_dm = data_dm_log['Univ BioChain']

rare_rnas = data_rnas_log['Univ Rare_log']
rare_dm = data_dm_log['Univ Rare']

wb_a_rnas = data_rnas_log['WB-Activated_log']
wb_a_dm = data_dm_log['WB-Activated']

wb_d_rnas = data_rnas_log['WB-Disease_log']
wb_d_dm=data_dm_log['WB-Disease']

immune_rnas = data_rnas_log['Univ ImmuneT10_log']
immune_dm=data_dm_log['Univ ImmuneT10']

hemat_rnas = data_rnas_log['Hemat System3_log']
hemat_dm = data_dm_log['Hemat System3']

print(f'The ANOVA analysis for the Brain sample is: {stats.f_oneway(brain_rnas,brain_dm)}')
print(f'The ANOVA analysis for the Univ Stratagene sample is: {stats.f_oneway(strata_rnas, strata_dm)}')
print(f'The ANOVA analysis for Univ DriverMap sample is: {stats.f_oneway(driver_rnas,driver_dm)}')
print(f'The ANOVA analysis for Univ Clontech sample is: {stats.f_oneway(clon_rnas, clon_dm)}')
print(f'The ANOVA analysis for Univ BioChain sample is: {stats.f_oneway(bioch_rnas,bioch_dm)}')
print(f'The ANOVA analysis for Univ Rare sample is: {stats.f_oneway(rare_rnas,rare_dm)}')
print(f'The ANOVA analysis for WB-Activated sample is: {stats.f_oneway(wb_a_rnas,wb_a_dm)}')
print(f'The ANOVA analysis for WB-Disease sample is: {stats.f_oneway(wb_d_rnas,wb_d_dm)}')
print(f'The ANOVA analysis for Univ Immune T10 sample is: {stats.f_oneway(immune_rnas,immune_dm)}')
print(f'The ANOVA analysis for Hemat System3 sample is: {stats.f_oneway(hemat_rnas,hemat_dm)}')
# Out:
# The ANOVA analysis for the Brain sample is: F_onewayResult(statistic=146.35413409476448, pvalue=1.252670961665098e-33)
# The ANOVA analysis for the Univ Stratagene sample is: F_onewayResult(statistic=12.01314654448065, pvalue=0.000528849554049396)
# The ANOVA analysis for Univ DriverMap sample is: F_onewayResult(statistic=56.132661026437695, pvalue=6.921149145327229e-14)
# The ANOVA analysis for Univ Clontech sample is: F_onewayResult(statistic=86.82179135947271, pvalue=1.2492785847437151e-20)
# The ANOVA analysis for Univ BioChain sample is: F_onewayResult(statistic=305.93798791292977, pvalue=3.104800217713843e-68)
# The ANOVA analysis for Univ Rare sample is: F_onewayResult(statistic=100.03488274550374, pvalue=1.6012387021436118e-23)
# The ANOVA analysis for WB-Activated sample is: F_onewayResult(statistic=125.34652406411948, pvalue=4.746441006426589e-29)
# The ANOVA analysis for WB-Disease sample is: F_onewayResult(statistic=57.81758683983353, pvalue=2.942013445116459e-14)
# The ANOVA analysis for Univ Immune T10 sample is: F_onewayResult(statistic=41.81418231045306, pvalue=1.0158915553244771e-10)
# The ANOVA analysis for Hemat System3 sample is: F_onewayResult(statistic=128.30849138858414, pvalue=1.0723788812185253e-29)

# %% [markdown]
# * From doing heatmaps, scatter and KDE, we make the following partial conclusions:
#     - The two techniques seem to have similar coverage of genes, with both having a high density of low expressing genes or even genes that aren't pick up at all.
#     - There appears to be some correlation between the two techniques for the genes with high-expression levels.
# * From the ANOVA analysis we can say that the two techniques are significantly different

# %% [markdown]
# ## Analysis of detection ability of both techniques by level of expression of genes

# %%
# Looking for max value to make up bins
print(data_rnas_log.max())
print(data_dm_log.max())
# Out:
# Brain_log              13.903312
# Univ Stratagene_log    14.583315
# Univ DriverMap_log     14.943352
# Univ Clontech_log      16.085180
# Univ BioChain_log      16.124078
# Univ Rare_log          15.296279
# WB-Activated_log       14.428116
# WB-Disease_log         15.530854
# Univ ImmuneT10_log     14.854120
# Hemat System3_log      14.756254
# dtype: float64
# Brain              15.099557
# Univ Stratagene    13.344532
# Univ DriverMap     13.315348
# Univ Clontech      13.558564
# Univ BioChain      15.569598
# Univ Rare          13.873098
# WB-Activated       14.635486
# WB-Disease         13.637191
# Univ ImmuneT10     14.502770
# Hemat System3      14.745118
# dtype: float64

# %%
# Make bins and function to cut df in 4 categories: genes that aren't pick up by the technique ("no read"), genes with 
# low, medium and high log of number of TPM (level of expression)

bins = [-1,0,5,10,17]
bin_labels = ['no read','low','medium','high']

def bin_logs(df):
    
    # Make empty dictionary to fill with column cut in bins
    bin_data = {}
    # Make empty dictionary to fill with count of genes per bin
    bin_group = {}
    
    for i in list(df.columns):
        bin_data[i] = pd.cut(df[i],bins,labels=bin_labels)
    
    # Make temporary df with binned data
    bin_dataf = pd.DataFrame.from_dict(bin_data)
    
    # Make df with counts of gene grouped by bin
    for j in list(bin_dataf.columns):
        gr_count = bin_dataf.groupby(j)[j].count()
        bin_group[j] = gr_count
    
    # Make final df with counts of gene by bin
    final_d = pd.DataFrame.from_dict(bin_group)
    
    return final_d

# %%
# Apply bin function to get counts of gene by bin for each technique

binned_rnas_data = bin_logs(data_rnas_log)
binned_rnas_data
# Out:
#          Brain_log  Univ Stratagene_log  Univ DriverMap_log  \
# no read       3973                 4418                4832
# low           8496                 9253                8670
# medium        6450                 5186                5362
# high            70                  132                 125
#
#          Univ Clontech_log  Univ BioChain_log  Univ Rare_log  \
# no read               2393               4693           2636
# low                  10311              10455          10264
# medium                6230               3728           5987
# high                    55                113            102
#
#          WB-Activated_log  WB-Disease_log  Univ ImmuneT10_log  \
# no read              6585            6406                2998
# low                  7830            8602               11192
# medium               4435            3833                4665
# high                  139             148                 134
#
#          Hemat System3_log
# no read               3841
# low                  10466
# medium                4544
# high                   138

# %%
binned_dm_data = bin_logs(data_dm_log)
binned_dm_data
# Out:
#          Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  Univ BioChain  \
# no read   4554             4370            5439           2516           5909
# low       8807             9396            8505          10688           9829
# medium    5547             5114            4930           5697           3136
# high        81              109             115             88            115
#
#          Univ Rare  WB-Activated  WB-Disease  Univ ImmuneT10  Hemat System3
# no read       2840          7029        6485            3511           4606
# low          10618          8026        7586           10610          10066
# medium        5431          3812        4805            4767           4192
# high           100           122         113             101            125

# %%
# Heatmaps to vizualize difference in counts of genes by level of expression

fig = plt.figure(figsize = (10,5)) 
ax1 = fig.add_subplot(1, 2, 1) 
ax2 = fig.add_subplot(1, 2, 2
                     )
sns.heatmap(binned_rnas_data, cmap = 'YlGnBu', ax = ax1) 
plt.setp(ax1.yaxis.get_majorticklabels(), rotation = 0)
ax1.set_title('RNAseq')

sns.heatmap(binned_dm_data, cmap = 'YlGnBu', ax = ax2, cbar_kws = {'label':'Number of genes'})
plt.setp(ax2.yaxis.get_majorticklabels(), rotation = 0)
ax2.set_title('DriverMap')

plt.tight_layout()

# %%
# Bar plots to better visualize the difference in count of genes by level of expression by sample

plt.figure(figsize=(25,15))

for i in range(10):
    title_font = {'size':'20'}
    plt.subplot(2,5,i+1)
    plt.bar(x = binned_rnas_data.index, height = binned_rnas_data.iloc[:,i], alpha=0.7, color='red',label='RNAseq')
    plt.bar(x = binned_rnas_data.index, height = binned_dm_data.iloc[:,i], alpha=0.5, color='blue',label='DM')
    plt.title(binned_dm_data.columns[i],**title_font)
    plt.xlabel('level of expression')
    plt.ylabel('number of genes')
    plt.legend()
    
plt.tight_layout()

# %% [markdown]
# * Partial conclusion: DriverMap seems to consistently have more genes unread than RNAseq

# %% [markdown]
# ## Analysis of detection of high expressing genes by samples by both techniques

# %%
# Make back df for only TPM data for RNAseq

data_tpm_rnas = data_rnas.iloc[:,0:10]
data_tpm_rnas.head()
# Out:
#                  Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# target gene
# 14266|CENPU   2.153935        42.743575       51.583525      18.622583
# 13331|PEX14  37.341275        15.845198       15.942073      51.209025
# 6630|RAD52   10.436083        21.691725       13.252975       7.072937
# 16802|CLYBL  11.338755         8.822482        4.750612      20.617875
# 6645|RANBP1  65.908950       346.465250      226.077000     127.275900
#
#              Univ BioChain   Univ Rare  WB-Activated  WB-Disease  \
# target gene
# 14266|CENPU       3.504800   58.203800      1.938013   64.565900
# 13331|PEX14      17.724160   23.905800     20.258400   22.871142
# 6630|RAD52        5.070735    7.610290     11.173897    4.872158
# 16802|CLYBL      26.773325    9.021778      4.565878   13.185607
# 6645|RANBP1      48.031900  102.964925     89.185500  171.035500
#
#              Univ ImmuneT10  Hemat System3
# target gene
# 14266|CENPU        7.413818      20.406225
# 13331|PEX14       21.287950      19.916900
# 6630|RAD52        11.987092      11.846675
# 16802|CLYBL        7.269315      10.624565
# 6645|RANBP1       75.948850     103.267950

# %%
# Make back df for only TPM data for RNAseq

data_tpm_dm = data_dm.iloc[:,0:10]
data_tpm_dm.head()
# Out:
#                  Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# target gene
# 14266|CENPU   0.294876         43.10860        70.50920       21.41510
# 13331|PEX14  27.671900         25.00070        17.33890       25.84810
# 6630|RAD52    5.274080          6.98958         3.28098        4.90895
# 16802|CLYBL  16.894700         14.28180         4.92852       30.36700
# 6645|RANBP1  45.997900        218.58800       143.56100       82.09650
#
#              Univ BioChain  Univ Rare  WB-Activated  WB-Disease  \
# target gene
# 14266|CENPU        1.14305   47.16210       1.43697    96.96370
# 13331|PEX14       12.43200   18.08010      10.52050    29.29620
# 6630|RAD52         1.53928    5.35737       1.73986     4.92102
# 16802|CLYBL       28.94250   15.52040       7.25044    18.39990
# 6645|RANBP1       30.95460   70.32010      51.50090   134.60400
#
#              Univ ImmuneT10  Hemat System3
# target gene
# 14266|CENPU        17.60490       23.53280
# 13331|PEX14        19.08750       14.08670
# 6630|RAD52          3.66106        4.29017
# 16802|CLYBL        11.47500       12.58540
# 6645|RANBP1        71.64050       79.22280

# %%
# Make function to get back genes binned as high expressing

def find_highs(df):
    high_genes = {}
    samples = list(df.columns)
    
    for sample in samples:
        sample_cut = pd.cut(df[sample], bins, labels = bin_labels)
        sample_cut = sample_cut[sample_cut == 'high']
        high_genes[sample] = sample_cut
    
    return high_genes

# %%
# Find high expressing genes for RNAseq
high_rnas = find_highs(data_rnas_log)

# Find high expressing genes for DM
high_dm = find_highs(data_dm_log)

# %%
high_brain = {}
high_brain['rnas'] = high_rnas['Brain_log']
high_brain['dm'] = high_dm['Brain']
high_brain_df = pd.DataFrame.from_dict(high_brain)
# Out:
#                 rnas    dm
# 100049|SLC26A4  high  high
# 100101|TUBB4A   high   NaN
# 100167|PBOV1    high   NaN
# 100195|TUBA1C   high  high
# 100205|ZNF486   high   NaN

# %%
# Difference in number of high expressed genes

print(high_brain_df['rnas'].value_counts() - high_brain_df['dm'].value_counts())
# Out:
# high      -11
# medium      0
# low         0
# no read     0
# dtype: int64

# %%
# Get back values of TPM of high genes for sample Brain

# Make a dictionary with keys = gene name, and values = TPM
col_dict={}
for index, row in high_brain_df.iterrows():
    col_dict[index]=row
    
# Make new dictionary with values of TPM per gene for every sample
keys = list(col_dict.keys())
val_dict = {}
val_dict_dm = {}
for i in keys:
    val_dict[i] = data_tpm_rnas.loc[i,'Brain']
for i in keys:
    val_dict_dm[i] = data_tpm_dm.loc[i,'Brain']

high_brain_tpm = pd.DataFrame([val_dict,val_dict_dm]).T
high_brain_tpm = high_brain_tpm.rename(columns={0:'RNAseq',1:'DM'})
high_brain_tpm.head()
# Out:
#                    RNAseq           DM
# 100049|SLC26A4  4156.6500  3475.440000
# 100101|TUBB4A   1125.8855   470.226000
# 100167|PBOV1    4480.5400     0.299972
# 100195|TUBA1C   2754.5900  2703.720000
# 100205|ZNF486   3387.9325     4.473880

# %%
stats.chisquare(high_brain_tpm['DM'],high_brain_tpm['RNAseq'])
# Out:
# Power_divergenceResult(statistic=471346.28265256766, pvalue=0.0)

# %%
# Make new column with difference between both techniques

high_brain_tpm['Diff'] = high_brain_tpm['DM'] - high_brain_tpm['RNAseq']
high_brain_tpm.head()
# Out:
#                    RNAseq           DM         Diff
# 100049|SLC26A4  4156.6500  3475.440000  -681.210000
# 100101|TUBB4A   1125.8855   470.226000  -655.659500
# 100167|PBOV1    4480.5400     0.299972 -4480.240028
# 100195|TUBA1C   2754.5900  2703.720000   -50.870000
# 100205|ZNF486   3387.9325     4.473880 -3383.458620

# %%
high_brain_tpm['Diff'].sum()
# Out:
# 8661.508851999994

# %%
# Take log of difference as absolute value

high_brain_tpm['Diff'] = high_brain_tpm['Diff'].apply(np.abs)
high_brain_tpm['Diff'] = high_brain_tpm['Diff'].apply(log2)
high_brain_tpm.head()
# Out:
#                    RNAseq           DM       Diff
# 100049|SLC26A4  4156.6500  3475.440000   9.411956
# 100101|TUBB4A   1125.8855   470.226000   9.356803
# 100167|PBOV1    4480.5400     0.299972  12.129360
# 100195|TUBA1C   2754.5900  2703.720000   5.668743
# 100205|ZNF486   3387.9325     4.473880  11.724283

# %%
plt.figure(figsize=(20,5))
plt.bar(x=high_brain_tpm.index, height=high_brain_tpm['Diff'])
# Out:
# <BarContainer object of 121 artists>

# %%
# Plot of diff number og high genes by sample

# %% [markdown]
# # Is it worth this?

# %%
# Get max to make new bins for binning into similarity bins

high_brain_tpm.max()
# Out:
# RNAseq    15321.950000
# DM        35109.100000
# Diff         14.858866
# dtype: float64

# %%
#  REMOVE....................
# Get back values of TPM of only high expressing genes for RNAseq

# Make a dictionary with keys = gene name, and values = row of df
col_dict={}
for index, row in high_rnas.iterrows():
    col_dict[index]=row

# Make new dictionary with values of TPM per gene for every sample
keys=list(col_dict.keys())
val_dict={}
for i in keys:
    val_dict[i] = data_tpm_rnas.loc[i,:]

# Make up back df with values of TPM per gene per sample 
high_val_rnas_df = pd.DataFrame.from_dict(val_dict).transpose()
high_val_rnas_df.head()
# Out:
#                         Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# 10001|A2M           205.99175       327.422000       116.24495      911.63975
# 100049|SLC26A4     4156.65000      2918.340000      3651.97750     5157.65750
# 100078|HIST1H2AJ     15.42380      1136.453500       975.46300      100.05045
# 100082|HIST2H2AA3    46.30560       993.901000       979.04525      223.31150
# 100101|TUBB4A      1125.88550         3.971662         1.82802      221.51325
#
#                    Univ BioChain    Univ Rare  WB-Activated  WB-Disease  \
# 10001|A2M            1353.040000   542.638500     12.088445     7.98167
# 100049|SLC26A4       2534.125000  3628.122500   3970.142500  1094.78675
# 100078|HIST1H2AJ       26.765625   155.352500     28.384175  2655.30000
# 100082|HIST2H2AA3      72.685950   153.144500    302.830250  1322.42750
# 100101|TUBB4A           1.758870    13.603425      0.000000     9.10376
#
#                    Univ ImmuneT10  Hemat System3
# 10001|A2M              606.828500    1218.647500
# 100049|SLC26A4        2760.797500    3063.890000
# 100078|HIST1H2AJ        16.146925      39.875575
# 100082|HIST2H2AA3       46.953450     101.786850
# 100101|TUBB4A          406.808750      10.119405

# %%
# REMOVE....................
# Same reconstruction, but now for DM samples

col_dict_dm = {}
for index, row in high_dm.iterrows():
    col_dict_dm[index] = row

keys_dm = list(col_dict_dm.keys())
val_dict_dm = {}
for i in keys:
    val_dict_dm[i] = data_tpm_dm.loc[i,:]

high_val_dm_df = pd.DataFrame.from_dict(val_dict_dm).transpose()
high_val_dm_df.head()
# Out:
#                        Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# 10001|A2M           337.4980        630.55000       218.45500      2016.9300
# 100049|SLC26A4     3475.4400      10401.70000     10193.40000      8929.6300
# 100078|HIST1H2AJ     91.2011       3602.44000      4433.69000       906.4010
# 100082|HIST2H2AA3    17.3088        433.02400       314.17600       102.2400
# 100101|TUBB4A       470.2260          2.82788         1.41061        83.9339
#
#                    Univ BioChain  Univ Rare  WB-Activated   WB-Disease  \
# 10001|A2M            2181.570000  1039.2900      11.24110     63.42630
# 100049|SLC26A4       2478.010000  8240.4400    6049.41000   1917.92000
# 100078|HIST1H2AJ      136.162000  1023.8500     143.65700  10598.90000
# 100082|HIST2H2AA3      40.970900    86.3120      94.81460    594.59500
# 100101|TUBB4A           0.351055    16.4886       1.23335      2.52812
#
#                    Univ ImmuneT10  Hemat System3
# 10001|A2M               1567.8500      3008.3700
# 100049|SLC26A4          3458.1000      5641.7500
# 100078|HIST1H2AJ         236.5180       339.0330
# 100082|HIST2H2AA3         13.1017        28.0870
# 100101|TUBB4A            238.6470        13.0249

# %%
# REMOVE--------------------
# Make a new df with the difference between TPM for RNAseq and DM

diff_dict = {}
for column in list(high_val_rnas_df.columns):
    diff_dict[column] = high_val_rnas_df[column] - high_val_dm_df[column]
    difference_df = pd.DataFrame.from_dict(diff_dict)
    
difference_df.head()
# Out:
#                        Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# 10001|A2M         -131.50625      -303.128000      -102.21005    -1105.29025
# 100049|SLC26A4     681.21000     -7483.360000     -6541.42250    -3771.97250
# 100078|HIST1H2AJ   -75.77730     -2465.986500     -3458.22700     -806.35055
# 100082|HIST2H2AA3   28.99680       560.877000       664.86925      121.07150
# 100101|TUBB4A      655.65950         1.143782         0.41741      137.57935
#
#                    Univ BioChain    Univ Rare  WB-Activated  WB-Disease  \
# 10001|A2M            -828.530000  -496.651500      0.847345   -55.44463
# 100049|SLC26A4         56.115000 -4612.317500  -2079.267500  -823.13325
# 100078|HIST1H2AJ     -109.396375  -868.497500   -115.272825 -7943.60000
# 100082|HIST2H2AA3      31.715050    66.832500    208.015650   727.83250
# 100101|TUBB4A           1.407815    -2.885175     -1.233350     6.57564
#
#                    Univ ImmuneT10  Hemat System3
# 10001|A2M             -961.021500   -1789.722500
# 100049|SLC26A4        -697.302500   -2577.860000
# 100078|HIST1H2AJ      -220.371075    -299.157425
# 100082|HIST2H2AA3       33.851750      73.699850
# 100101|TUBB4A          168.161750      -2.905495

# %%
# REMOVE......................
# Take log of difference as absolute value

difference_df = difference_df.apply(np.abs)

# Apply log function we created and get back df with only log values (remember that function 
#adds column with log to original)

log_df(difference_df)
diff_log_df = difference_df.iloc[:,10:21]
diff_log_df.head()
# Out:
#                    Brain_log  Univ Stratagene_log  Univ DriverMap_log  \
# 10001|A2M           7.038988             8.243783            6.675393
# 100049|SLC26A4      9.411956            12.869470           12.675389
# 100078|HIST1H2AJ    6.243694            11.267949           11.755817
# 100082|HIST2H2AA3   4.857822             9.131541            9.376927
# 100101|TUBB4A       9.356803             0.193813            0.000000
#
#                    Univ Clontech_log  Univ BioChain_log  Univ Rare_log  \
# 10001|A2M                  10.110210           9.694410       8.956090
# 100049|SLC26A4             11.881103           5.810315      12.171276
# 100078|HIST1H2AJ            9.655263           6.773421       9.762378
# 100082|HIST2H2AA3           6.919715           4.987096       6.062478
# 100101|TUBB4A               7.104120           0.493458       1.528659
#
#                    WB-Activated_log  WB-Disease_log  Univ ImmuneT10_log  \
# 10001|A2M                  0.000000        5.792976            9.908425
# 100049|SLC26A4            11.021860        9.684982            9.445641
# 100078|HIST1H2AJ           6.848909       12.955577            7.783791
# 100082|HIST2H2AA3          7.700548        9.507463            5.081159
# 100101|TUBB4A              0.302582        2.717131            7.393706
#
#                    Hemat System3_log
# 10001|A2M                  10.805520
# 100049|SLC26A4             11.331958
# 100078|HIST1H2AJ            8.224761
# 100082|HIST2H2AA3           6.203590
# 100101|TUBB4A               1.538784

# %%
# Get max of each sample to make new bins for binning into similarity bins
diff_log_df.describe()
# Out:
#         Brain_log  Univ Stratagene_log  Univ DriverMap_log  Univ Clontech_log  \
# count  388.000000           388.000000          388.000000         388.000000
# mean     6.001953             6.955663            6.407867           7.270873
# std      3.774898             3.973180            4.215260           2.943971
# min      0.000000             0.000000            0.000000           0.000000
# 25%      2.370022             3.599937            2.135579           5.719617
# 50%      7.173272             8.088464            7.794430           8.049406
# 75%      9.079193            10.221508           10.054283           9.248024
# max     14.858866            14.582449           14.942413          16.084490
#
#        Univ BioChain_log  Univ Rare_log  WB-Activated_log  WB-Disease_log  \
# count         388.000000     388.000000        388.000000      388.000000
# mean            7.394851       7.067282          6.181830        6.321017
# std             3.311344       3.583787          4.480006        4.611738
# min             0.000000       0.000000          0.000000        0.000000
# 25%             5.306191       4.893064          1.120597        0.583474
# 50%             8.142181       7.999560          7.157932        7.715605
# 75%             9.607867       9.837304         10.225980       10.445746
# max            16.118394      15.295204         14.550875       15.530152
#
#        Univ ImmuneT10_log  Hemat System3_log
# count          388.000000         388.000000
# mean             7.658082           7.495325
# std              3.413310           3.670589
# min              0.000000           0.000000
# 25%              5.426517           4.961755
# 50%              8.492246           8.265169
# 75%             10.333273          10.463272
# max             14.846347          14.750344

# %%
# Define new bins for grade of similarity

diff_bins = [0,5,10,17]
bin_diff_labels = ['high similarity','medium similarity','different']

# %%
# Define new bins for grade of similarity

diff_bins = [0,5,10,17]
bin_diff_labels = ['high similarity','medium similarity','different']

# %%
# Make new binning function that gets back df with count of genes by similarity

def bin_diff_logs(df):
    bin_data = {}
    bin_group = {}
    for i in list(df.columns):
        bin_data[i] = pd.cut(df[i], diff_bins, labels = bin_diff_labels)
    bin_dataf = pd.DataFrame.from_dict(bin_data)
    for j in list(bin_dataf.columns):
        gr_count = bin_dataf.groupby(j)[j].count()
        bin_group[j] = gr_count
    final_d = pd.DataFrame.from_dict(bin_group)
    
    return final_d

# %%
# Binning of log of difference df by using function to bin

bin_diff_log_df = bin_diff_logs(diff_log_df)
bin_diff_log_df
# Out:
#                    Brain_log  Univ Stratagene_log  Univ DriverMap_log  \
# high similarity           86                   85                  79
# medium similarity        210                  156                 141
# different                 40                  116                 103
#
#                    Univ Clontech_log  Univ BioChain_log  Univ Rare_log  \
# high similarity                   71                 76             80
# medium similarity                258                225            201
# different                         50                 74             86
#
#                    WB-Activated_log  WB-Disease_log  Univ ImmuneT10_log  \
# high similarity                  79              58                  64
# medium similarity               119             123                 188
# different                       111             119                 116
#
#                    Hemat System3_log
# high similarity                   75
# medium similarity                167
# different                        123

# %%
# Bar plot to visualize similarity by sample

fig = plt.figure(figsize=(25,15))
st = fig.suptitle('Number of genes with given similarity by sample', fontsize=24)
for i in range(10):
    title_font = {'size':'20'}
    plt.subplot(2,5,i+1)
    plt.bar(x = bin_diff_log_df.index, height = bin_diff_log_df.iloc[:,i], alpha=0.7, color='red')
    plt.title(data_dm_log.columns[i],**title_font)

# Making global title position by adjusting plots position
st.set_y(1.05)
fig.subplots_adjust(top=0.85)
   
plt.tight_layout()
