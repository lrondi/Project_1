# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import log2
from scipy.stats import chi2_contingency
import seaborn as sns

# %%
data=pd.read_csv('rnaSeqTPM.tsv',delimiter='\t')
data.head()
# Out:
#         target  AC-10_L001-ds.a84fdb211ec34671aca066ec644cf980  \
# 0  14266|CENPU                                         26.5465
# 1  13331|PEX14                                         14.7797
# 2   6630|RAD52                                         10.6624
# 3  16802|CLYBL                                         14.9415
# 4  6645|RANBP1                                        120.0090
#
#    AC-10_L002-ds.2ddd07759d0049598e038c6f5ba208fa  \
# 0                                         16.2036
# 1                                         30.2357
# 2                                         11.1358
# 3                                         15.5777
# 4                                         95.8606
#
#    AC-10_L003-ds.c54fbdfec6c64f5f9b34d857bdc2d39b  \
# 0                                        15.82680
# 1                                        14.57500
# 2                                        14.51280
# 3                                         5.08468
# 4                                       115.83400
#
#    AC-10_L004-ds.2bd4291178074656a4052e86fe3a627e  \
# 0                                        23.04800
# 1                                        20.07720
# 2                                        11.07570
# 3                                         6.89438
# 4                                        81.36820
#
#    AC-1_L001-ds.4e1b9a9de76b4859a777b1e85ee85940  \
# 0                                        4.27284
# 1                                       25.98820
# 2                                       10.32110
# 3                                       19.27520
# 4                                       65.89110
#
#    AC-1_L002-ds.01aba20a131d47c1ab69483d8ec077ec  \
# 0                                        4.34290
# 1                                       53.11600
# 2                                        7.00181
# 3                                        3.27223
# 4                                       52.77280
#
#    AC-1_L003-ds.88a026919bd04bc5a4216cb9f1c13b9f  \
# 0                                        0.00000
# 1                                       34.81970
# 2                                        6.95342
# 3                                        6.50129
# 4                                       55.74450
#
#    AC-1_L004-ds.7f15d836c940438a91be474a714f4b2c  \
# 0                                         0.0000
# 1                                        35.4412
# 2                                        17.4680
# 3                                        16.3063
# 4                                        89.2274
#
#    AC-2_L001-ds.857a9a7bb18646108f52f84bc5b08aaf  \
# 0                                       49.09530
# 1                                       20.75710
# 2                                       25.68350
# 3                                        2.67345
# 4                                      436.34000
#
#                        ...                        \
# 0                      ...
# 1                      ...
# 2                      ...
# 3                      ...
# 4                      ...
#
#    AC-7_L003-ds.90fc01aaf24b45caa6e05a27f56c79a1  \
# 0                                        3.85098
# 1                                       23.94680
# 2                                        9.45641
# 3                                        0.00000
# 4                                      124.60800
#
#    AC-7_L004-ds.422324df17bb4355a209d2e206d4ebc0  \
# 0                                        0.00000
# 1                                       24.49580
# 2                                        6.51098
# 3                                       12.25740
# 4                                       83.27780
#
#    AC-8_L001-ds.b12e8f44abb04463b2f39d8752f94941  \
# 0                                       80.97500
# 1                                        9.05497
# 2                                        3.51170
# 3                                       16.36970
# 4                                      142.70700
#
#    AC-8_L002-ds.a0c59a8dc0f24e30aec2c8d0a17334ca  \
# 0                                       61.55940
# 1                                       13.72040
# 2                                        3.51882
# 3                                       14.76480
# 4                                      171.49800
#
#    AC-8_L003-ds.e77040b8045f45478d3aeef2c419abb9  \
# 0                                       50.31760
# 1                                       41.40420
# 2                                        8.84862
# 3                                       14.85800
# 4                                      198.41100
#
#    AC-8_L004-ds.04e2a2a871c145e49fb29ada5cf53c09  \
# 0                                       65.41160
# 1                                       27.30500
# 2                                        3.60949
# 3                                        6.74993
# 4                                      171.52600
#
#    AC-9_L001-ds.a46dbd8c24a44ddea892e43e28a4ba93  \
# 0                                        2.26704
# 1                                       18.80870
# 2                                        9.13044
# 3                                       11.92510
# 4                                       86.65530
#
#    AC-9_L002-ds.bbb091f5bbca4f889ad07186bc5d1f49  \
# 0                                        2.31271
# 1                                       37.86440
# 2                                       14.82380
# 3                                        5.18773
# 4                                      105.10300
#
#    AC-9_L003-ds.194a0d6a4ab447dab95363ede97522f3  \
# 0                                       18.11890
# 1                                       14.20190
# 2                                        7.27973
# 3                                        8.49613
# 4                                       47.65850
#
#    AC-9_L004-ds.9eb4326b03f84467a6b399d8f09fd9da
# 0                                        6.95662
# 1                                       14.27680
# 2                                       16.71440
# 3                                        3.46830
# 4                                       64.37860
#
# [5 rows x 41 columns]

# %%
data=data.rename(columns={'AC-10_L001-ds.a84fdb211ec34671aca066ec644cf980':'AC10_1',
       'AC-10_L002-ds.2ddd07759d0049598e038c6f5ba208fa':'AC10_2','AC-10_L003-ds.c54fbdfec6c64f5f9b34d857bdc2d39b':'AC10_3',
       'AC-10_L004-ds.2bd4291178074656a4052e86fe3a627e':'AC10_4','AC-1_L001-ds.4e1b9a9de76b4859a777b1e85ee85940':'AC1_1',
       'AC-1_L002-ds.01aba20a131d47c1ab69483d8ec077ec':'AC1_2','AC-1_L003-ds.88a026919bd04bc5a4216cb9f1c13b9f':'AC1_3',
       'AC-1_L004-ds.7f15d836c940438a91be474a714f4b2c':'AC1_4','AC-2_L001-ds.857a9a7bb18646108f52f84bc5b08aaf':'AC2_1',
       'AC-2_L002-ds.5a9da74220064ee89a9736bc85a52179':'AC2_2','AC-2_L003-ds.e6194500d53a4f33bfc7915c64a5beeb':'AC2_3',
       'AC-2_L004-ds.246b173490c3494a8eeea8621ec361d1':'AC2_4','AC-3_L001-ds.58010ec40df84a978e4af7d1a23d1af9':'AC3_1',
       'AC-3_L002-ds.454403b9d0ac4d72af1220546b5a630d':'AC3_2','AC-3_L003-ds.d83a7a6dd4c545b1b2170c1100cf2120':'AC3_3',
       'AC-3_L004-ds.6cf9ff6076264856a74212cfc7410e96':'AC3_4','AC-4_L001-ds.e45254993f044e7da3deb87a28e560a4':'AC4_1',
       'AC-4_L002-ds.fcf9658251c14b40b7ed788a6f9d1adb':'AC4_2','AC-4_L003-ds.109477542e734e6c8c93bedd405a3039':'AC4_3',
       'AC-4_L004-ds.d101269468414b71a926cd9fc76cb004':'AC4_4','AC-5_L001-ds.bd13708d4f784119ac0a2ae972e37f66':'AC5_1',
       'AC-5_L002-ds.ffd221b8bc164be3b6d604985219be02':'AC5_2','AC-5_L003-ds.8d1b59e10e7b4ae7bd089b99744e3802':'AC5_3',
       'AC-5_L004-ds.9b5362075da148408cb715587ce595a5':'AC5_4','AC-6_L001-ds.3ab380d9704849cda96aed57e96e6586':'AC6_1',
data.head()
# Out:
#         target    AC10_1   AC10_2     AC10_3    AC10_4     AC1_1     AC1_2  \
# 0  14266|CENPU   26.5465  16.2036   15.82680  23.04800   4.27284   4.34290
# 1  13331|PEX14   14.7797  30.2357   14.57500  20.07720  25.98820  53.11600
# 2   6630|RAD52   10.6624  11.1358   14.51280  11.07570  10.32110   7.00181
# 3  16802|CLYBL   14.9415  15.5777    5.08468   6.89438  19.27520   3.27223
# 4  6645|RANBP1  120.0090  95.8606  115.83400  81.36820  65.89110  52.77280
#
#       AC1_3    AC1_4      AC2_1    ...            AC10        AC1         AC2  \
# 0   0.00000   0.0000   49.09530    ...       20.406225   2.153935   42.743575
# 1  34.81970  35.4412   20.75710    ...       19.916900  37.341275   15.845198
# 2   6.95342  17.4680   25.68350    ...       11.846675  10.436083   21.691725
# 3   6.50129  16.3063    2.67345    ...       10.624565  11.338755    8.822482
# 4  55.74450  89.2274  436.34000    ...      103.267950  65.908950  346.465250
#
#           AC3         AC4        AC5         AC6        AC7         AC8  \
# 0   51.583525   18.622583   3.504800   58.203800   1.938013   64.565900
# 1   15.942073   51.209025  17.724160   23.905800  20.258400   22.871142
# 2   13.252975    7.072937   5.070735    7.610290  11.173897    4.872158
# 3    4.750612   20.617875  26.773325    9.021778   4.565878   13.185607
# 4  226.077000  127.275900  48.031900  102.964925  89.185500  171.035500
#
#          AC9
# 0   7.413818
# 1  21.287950
# 2  11.987092
# 3   7.269315
# 4  75.948850
#
# [5 rows x 51 columns]

# %%
data_m=data[['target','AC1','AC2','AC3','AC4','AC5','AC6','AC7','AC8','AC9','AC10']]
data_m=data_m.rename(columns={'target':'target gene','AC1':'Brain','AC2':'Univ Stratagene','AC3':'Univ DriverMap',
                             'AC4':'Univ Clontech','AC5':'Univ BioChain','AC6':'Univ Rare','AC7':'WB-Activated',
                             'AC8':'WB-Disease','AC9':'Univ ImmuneT10','AC10':'Hemat System3'})
data_m.head()
# Out:
#    target gene      Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# 0  14266|CENPU   2.153935        42.743575       51.583525      18.622583
# 1  13331|PEX14  37.341275        15.845198       15.942073      51.209025
# 2   6630|RAD52  10.436083        21.691725       13.252975       7.072937
# 3  16802|CLYBL  11.338755         8.822482        4.750612      20.617875
# 4  6645|RANBP1  65.908950       346.465250      226.077000     127.275900
#
#    Univ BioChain   Univ Rare  WB-Activated  WB-Disease  Univ ImmuneT10  \
# 0       3.504800   58.203800      1.938013   64.565900        7.413818
# 1      17.724160   23.905800     20.258400   22.871142       21.287950
# 2       5.070735    7.610290     11.173897    4.872158       11.987092
# 3      26.773325    9.021778      4.565878   13.185607        7.269315
# 4      48.031900  102.964925     89.185500  171.035500       75.948850
#
#    Hemat System3
# 0      20.406225
# 1      19.916900
# 2      11.846675
# 3      10.624565
# 4     103.267950

# %%
data_count=data_m['target gene'].count()
data_m=data_m.set_index('target gene')

# %% [markdown]
# Is there a noticeable difference in high/medium/low abundance of transcription expression detection ability for DM and RS? Plot: Heatmaps with log2 of reads and figure out thresholds (Both refine data. Leeza - DM samples, Luc - RS samples)

# %%
def log_df(df):
    columns_list=df.columns
    for column in columns_list:
        col_name=column+'_log'
        col_numbers=list(df[column])
        log_numbers=[]
        for num in col_numbers:
            if num>1:
                log_numbers.append(log2(num))
            else:
                log_numbers.append(0)
        df[col_name]=log_numbers

# %%
data_m2=data_m
log_df(data_m2)
data_m2.head()
# Out:
#                  Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# target gene
# 14266|CENPU   2.153935        42.743575       51.583525      18.622583
# 13331|PEX14  37.341275        15.845198       15.942073      51.209025
# 6630|RAD52   10.436083        21.691725       13.252975       7.072937
# 16802|CLYBL  11.338755         8.822482        4.750612      20.617875
# 6645|RANBP1  65.908950       346.465250      226.077000     127.275900
#
#              Univ BioChain   Univ Rare  WB-Activated  WB-Disease  \
# target gene
# 14266|CENPU       3.504800   58.203800      1.938013   64.565900
# 13331|PEX14      17.724160   23.905800     20.258400   22.871142
# 6630|RAD52        5.070735    7.610290     11.173897    4.872158
# 16802|CLYBL      26.773325    9.021778      4.565878   13.185607
# 6645|RANBP1      48.031900  102.964925     89.185500  171.035500
#
#              Univ ImmuneT10  Hemat System3  Brain_log  Univ Stratagene_log  \
# target gene
# 14266|CENPU        7.413818      20.406225   1.106975             5.417636
# 13331|PEX14       21.287950      19.916900   5.222699             3.985974
# 6630|RAD52        11.987092      11.846675   3.383508             4.439073
# 16802|CLYBL        7.269315      10.624565   3.503190             3.141185
# 6645|RANBP1       75.948850     103.267950   6.042402             8.436567
#
#              Univ DriverMap_log  Univ Clontech_log  Univ BioChain_log  \
# target gene
# 14266|CENPU            5.688838           4.218981           1.809332
# 13331|PEX14            3.994767           5.678326           4.147645
# 6630|RAD52             3.728244           2.822310           2.342195
# 16802|CLYBL            2.248114           4.365824           4.742724
# 6645|RANBP1            7.820670           6.991815           5.585921
#
#              Univ Rare_log  WB-Activated_log  WB-Disease_log  \
# target gene
# 14266|CENPU       5.863041          0.954578        6.012701
# 13331|PEX14       4.579289          4.340448        4.515457
# 6630|RAD52        2.927951          3.482061        2.284561
# 16802|CLYBL       3.173412          2.190892        3.720892
# 6645|RANBP1       6.686009          6.478737        7.418152
#
#              Univ ImmuneT10_log  Hemat System3_log
# target gene
# 14266|CENPU            2.890217           4.350937
# 13331|PEX14            4.411965           4.315921
# 6630|RAD52             3.583410           3.566410
# 16802|CLYBL            2.861819           3.409332
# 6645|RANBP1            6.246956           6.690249

# %%
data_log=data_m2.iloc[:,10:20]
data_log.head()
# Out:
#              Brain_log  Univ Stratagene_log  Univ DriverMap_log  \
# target gene
# 14266|CENPU   1.106975             5.417636            5.688838
# 13331|PEX14   5.222699             3.985974            3.994767
# 6630|RAD52    3.383508             4.439073            3.728244
# 16802|CLYBL   3.503190             3.141185            2.248114
# 6645|RANBP1   6.042402             8.436567            7.820670
#
#              Univ Clontech_log  Univ BioChain_log  Univ Rare_log  \
# target gene
# 14266|CENPU           4.218981           1.809332       5.863041
# 13331|PEX14           5.678326           4.147645       4.579289
# 6630|RAD52            2.822310           2.342195       2.927951
# 16802|CLYBL           4.365824           4.742724       3.173412
# 6645|RANBP1           6.991815           5.585921       6.686009
#
#              WB-Activated_log  WB-Disease_log  Univ ImmuneT10_log  \
# target gene
# 14266|CENPU          0.954578        6.012701            2.890217
# 13331|PEX14          4.340448        4.515457            4.411965
# 6630|RAD52           3.482061        2.284561            3.583410
# 16802|CLYBL          2.190892        3.720892            2.861819
# 6645|RANBP1          6.478737        7.418152            6.246956
#
#              Hemat System3_log
# target gene
# 14266|CENPU           4.350937
# 13331|PEX14           4.315921
# 6630|RAD52            3.566410
# 16802|CLYBL           3.409332
# 6645|RANBP1           6.690249

# %%
tab=data_log.transpose()
tab.head()
# Out:
# target gene          14266|CENPU  13331|PEX14  6630|RAD52  16802|CLYBL  \
# Brain_log               1.106975     5.222699    3.383508     3.503190
# Univ Stratagene_log     5.417636     3.985974    4.439073     3.141185
# Univ DriverMap_log      5.688838     3.994767    3.728244     2.248114
# Univ Clontech_log       4.218981     5.678326    2.822310     4.365824
# Univ BioChain_log       1.809332     4.147645    2.342195     4.742724
#
# target gene          6645|RANBP1  12149|KDF1  11733|TBC1D30  14535|TMEM258  \
# Brain_log               6.042402    2.245839       5.061035       6.693610
# Univ Stratagene_log     8.436567    2.963911       2.822148       8.210013
# Univ DriverMap_log      7.820670    4.729278       3.648200       7.627450
# Univ Clontech_log       6.991815    1.497970       3.318626       6.803169
# Univ BioChain_log       5.585921    1.712148       0.695954       6.224163
#
# target gene          12400|LRG1  11931|HYAL1     ...      16176|GAB3  \
# Brain_log              0.000000     4.054180     ...        0.000000
# Univ Stratagene_log    4.251886     3.756653     ...        0.685171
# Univ DriverMap_log     3.118327     0.785576     ...        0.000000
# Univ Clontech_log      3.478247     5.185426     ...        2.567949
# Univ BioChain_log      7.465277     6.353782     ...        0.000000
#
# target gene          13299|ZNF701  5706|NEB  15110|ZNF775  3181|CCNB2  \
# Brain_log                2.075561  0.337782      5.139967    0.000000
# Univ Stratagene_log      1.289013  0.064607      3.983449    6.592308
# Univ DriverMap_log       2.836249  1.458984      3.313137    6.048997
# Univ Clontech_log        1.039789  1.540372      4.355929    4.513309
# Univ BioChain_log        2.461696  0.000000      1.378955    1.755232
#
# target gene          16735|BBS12  14784|ANKRD27  3464|COL19A1  10238|TCTA  \
# Brain_log               2.449345       4.636225      3.332654    4.913491
# Univ Stratagene_log     0.000000       4.254808      0.000000    3.761934
# Univ DriverMap_log      0.793720       5.592719      0.000000    4.562096
# Univ Clontech_log       2.231803       5.537454      0.849012    4.562743
# Univ BioChain_log       0.178158       3.819152      0.000000    4.572714
#
# target gene          10545|CA5A
# Brain_log              0.000000
# Univ Stratagene_log    0.000000
# Univ DriverMap_log     0.000000
# Univ Clontech_log      0.000000
# Univ BioChain_log      4.058026
#
# [5 rows x 18989 columns]

# %%
leeza=pd.read_csv('DM_data_log_original.csv')
leeza=leeza.rename(columns={'Unnamed: 0':'target gene'})
leeza=leeza.set_index('target gene')
leeza.head()
# Out:
#                  14266|CENPU  13331|PEX14  6630|RAD52  16802|CLYBL  \
# target gene
# Brain               0.000000     4.790350    2.398919     4.078499
# Univ Stratagene     5.429904     4.643897    2.805206     3.836106
# Univ DriverMap      6.139740     4.115940    1.714127     2.301154
# Univ Clontech       4.420557     4.691986    2.295414     4.924432
# Univ BioChain       0.192889     3.635987    0.622256     4.855118
#
#                  6645|RANBP1  12149|KDF1  11733|TBC1D30  14535|TMEM258  \
# target gene
# Brain               5.523496    1.228763       4.103053       6.710173
# Univ Stratagene     7.772070    1.961342       2.042179       8.095830
# Univ DriverMap      7.165520    3.665779       3.331720       7.717162
# Univ Clontech       6.359249    2.496324       2.617870       6.586897
# Univ BioChain       4.952082    1.895225       0.000000       5.822544
#
#                  12400|LRG1  11931|HYAL1     ...      16176|GAB3  \
# target gene                                  ...
# Brain              0.000000     1.276145     ...        0.306146
# Univ Stratagene    2.952479     3.981332     ...        1.133307
# Univ DriverMap     2.640952     0.699054     ...        0.000000
# Univ Clontech      2.452421     4.728546     ...        2.585083
# Univ BioChain      6.381131     6.184342     ...        0.996779
#
#                  13299|ZNF701  5706|NEB  15110|ZNF775  3181|CCNB2  \
# target gene
# Brain                1.214970  0.332553      3.694891    0.000000
# Univ Stratagene      1.688910  0.000000      3.407176    3.999648
# Univ DriverMap       2.022876  0.497485      1.224682    3.687833
# Univ Clontech        0.755546  0.000000      3.172569    2.424041
# Univ BioChain        0.895566  0.289598      0.508003    0.000000
#
#                  16735|BBS12  14784|ANKRD27  3464|COL19A1  10238|TCTA  \
# target gene
# Brain               2.398799       5.263639      1.572458    4.136503
# Univ Stratagene     0.966903       5.717493      0.000000    3.399294
# Univ DriverMap      1.068299       5.943832      0.000000    3.814048
# Univ Clontech       1.751399       5.473982      0.000000    4.217626
# Univ BioChain       0.000000       3.774924      0.000000    3.042280
#
#                  10545|CA5A
# target gene
# Brain              0.000000
# Univ Stratagene    0.560686
# Univ DriverMap     0.000000
# Univ Clontech      0.000000
# Univ BioChain      3.868736
#
# [5 rows x 18989 columns]

# %%
leezat=leeza.transpose()
leezat=leezat.reset_index()
del leezat.index.name
leezat=leezat.drop(columns='NegC_B67')
leezat.head()
# Out:
# target gene        index     Brain  Univ Stratagene  Univ DriverMap  \
# 0            14266|CENPU  0.000000         5.429904        6.139740
# 1            13331|PEX14  4.790350         4.643897        4.115940
# 2             6630|RAD52  2.398919         2.805206        1.714127
# 3            16802|CLYBL  4.078499         3.836106        2.301154
# 4            6645|RANBP1  5.523496         7.772070        7.165520
#
# target gene  Univ Clontech  Univ BioChain  Univ Rare  WB-Activated  \
# 0                 4.420557       0.192889   5.559556      0.523030
# 1                 4.691986       3.635987   4.176331      3.395131
# 2                 2.295414       0.622256   2.421525      0.798971
# 3                 4.924432       4.855118   3.956094      2.858069
# 4                 6.359249       4.952082   6.135865      5.686526
#
# target gene  WB-Disease  Univ ImmuneT10  Hemat System3
# 0              6.599373        4.137905       4.556601
# 1              4.872642        4.254556       3.816262
# 2              2.298957        1.872261       2.101035
# 3              4.201626        3.520422       3.653679
# 4              7.072577        6.162704       6.307844

# %%
plt.figure(figsize=(20,4))
sns.heatmap(tab,xticklabels=False,yticklabels=True)
plt.title('Heatmap for RNAseq')
plt.figure(figsize=(20,4))
sns.heatmap(leeza,xticklabels=False,yticklabels=True)
plt.title('Heatmap for DM')
# Out:
# Text(0.5, 1.0, 'Heatmap for DM')

# %%
# Just smaller sample, to see how heatmaps looks for just 5 genes
mini_data=data_log.head()
mini_data=mini_data.transpose()
mini_leeza=leezat.head()
mini_leeza=mini_leeza.transpose()

plt.subplot(1,2,1)
labels=list(leezat.columns)
sns.heatmap(mini_data, yticklabels=labels) 
plt.subplot(1,2,2)
sns.heatmap(mini_leeza, yticklabels=labels)

# %%
data_log.describe()
# Out:
#           Brain_log  Univ Stratagene_log  Univ DriverMap_log  \
# count  18989.000000         18989.000000        18989.000000
# mean       3.629963             3.280922            3.257903
# std        2.587913             2.550655            2.630829
# min        0.000000             0.000000            0.000000
# 25%        1.118536             0.498149            0.000000
# 50%        4.016856             3.534752            3.512316
# 75%        5.582920             5.185687            5.255339
# max       13.903312            14.583315           14.943352
#
#        Univ Clontech_log  Univ BioChain_log  Univ Rare_log  WB-Activated_log  \
# count       18989.000000       18989.000000   18989.000000      18989.000000
# mean            3.844618           2.915842       3.758131          2.820843
# std             2.265241           2.458019       2.327459          2.709500
# min             0.000000           0.000000       0.000000          0.000000
# 25%             2.342039           0.063762       2.102677          0.000000
# 50%             4.123390           2.945600       4.046395          2.638276
# 75%             5.433558           4.632353       5.378845          4.921621
# max            16.085180          16.124078      15.296279         14.428116
#
#        WB-Disease_log  Univ ImmuneT10_log  Hemat System3_log
# count    18989.000000        18989.000000       18989.000000
# mean         2.666063            3.423367           3.243733
# std          2.598986            2.345787           2.440710
# min          0.000000            0.000000           0.000000
# 25%          0.000000            1.566802           0.762984
# 50%          2.462475            3.606753           3.428977
# 75%          4.676655            5.018108           4.981470
# max         15.530854           14.854120          14.756254

# %%
# Scatter plots RNAseq vs DM
fig, ax = plt.subplots(2,5,figsize=(20,10))
ax[0,0].scatter(x=data_log['Brain_log'],y=leeza['Brain'],s=5)
ax[0,0].set_title('Brain',fontsize=15)
ax[0,1].scatter(x=data_log['Univ Stratagene_log'],y=leeza['Univ Stratagene'],s=5)
ax[0,1].set_title('Stratagene',fontsize=15)
ax[0,2].scatter(x=data_log['Univ DriverMap_log'],y=leeza['Univ DriverMap'],s=5)
ax[0,2].set_title('DriverMap',fontsize=15)
ax[0,3].scatter(x=data_log['Univ Clontech_log'],y=leeza['Univ Clontech'],s=5)
ax[0,3].set_title('Clontech',fontsize=15)
ax[0,4].scatter(x=data_log['Univ BioChain_log'],y=leeza['Univ BioChain'],s=5)
ax[0,4].set_title('BioChain',fontsize=15)
ax[1,0].scatter(x=data_log['Univ Rare_log'],y=leeza['Univ Rare'],s=5)
ax[1,0].set_title('Rare',fontsize=15)
ax[1,1].scatter(x=data_log['WB-Activated_log'],y=leeza['WB-Activated'],s=5)
ax[1,1].set_title('WB Activated',fontsize=15)
ax[1,2].scatter(x=data_log['WB-Disease_log'],y=leeza['WB-Disease'],s=5)
ax[1,2].set_title('WB Disease',fontsize=15)
ax[1,3].scatter(x=data_log['Univ ImmuneT10_log'],y=leeza['Univ ImmuneT10'],s=5)
ax[1,3].set_title('Univ ImmuneT10',fontsize=15)
ax[1,4].scatter(x=data_log['Hemat System3_log'],y=leeza['Hemat System3'],s=5)
ax[1,4].set_title('Hemat System3',fontsize=15)
ax[1,0].set_xlabel('RNAseq fold change')
ax[1,0].set_ylabel('DriverMap fold change')

plt.tight_layout()

# %%
sns.jointplot(x=data_log['Brain_log'],y=leeza['Brain'],color='skyblue',kind='kde')
# Out:
# C:\Users\luron\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x=data_log_0['Brain_log'],y=data_log_0['Univ DriverMap_log'],color='skyblue',kind='kde')

# %%
data_log_0=data_log[(data_log != 0).all(1)]
data_log_0
# Out:
#                   Brain_log  Univ Stratagene_log  Univ DriverMap_log  \
# target gene
# 14266|CENPU        1.106975             5.417636            5.688838
# 13331|PEX14        5.222699             3.985974            3.994767
# 6630|RAD52         3.383508             4.439073            3.728244
# 16802|CLYBL        3.503190             3.141185            2.248114
# 6645|RANBP1        6.042402             8.436567            7.820670
# 14535|TMEM258      6.693610             8.210013            7.627450
# 11931|HYAL1        4.054180             3.756653            0.785576
# 14256|SRGN         7.715607             7.373966            5.919835
# 7822|UBE2D1        5.175858             4.387833            5.270658
# 6543|PTCD2         5.282290             5.155134            4.443802
# 3108|CAMKK2        7.625760             3.504655            4.000584
# 11649|GRAMD4       4.823078             4.084696            5.005562
# 3387|CLCN2         3.648235             3.607869            1.906817
# 10214|TAF5         1.921684             1.977348            2.081424
# 10390|ZNF146       5.332523             5.446870            5.905364
# 13447|POLK         5.662665             5.354977            4.937830
# 12237|SNX24        4.615630             4.407866            4.759316
# 3948|EIF1B         7.274886             5.750270            5.250799
# 2912|BCAR3         4.187469             4.119474            6.380163
# 5875|NUP58         5.106106             5.824392            6.136705
# 15466|FNIP1        4.575011             3.746716            3.928742
# 9404|FER           5.966713             4.669689            4.092360
# 700|CD74           7.660279             6.323258            3.714898
# 13332|CAND1        7.429909             7.280592            7.222800
# 2747|ARHGAP5       8.414260             6.614146            7.107719
# 10874|APBA3        3.434717             3.492708            2.981954
# 2612|ALAD          7.174616             5.761547            5.890849
# 11326|ZNF274       3.978102             3.863190            4.523419
# 17847|ATP9B        2.784066             1.087512            2.003839
# 7689|TOMM22        4.775397             5.192704            6.225454
# ...                     ...                  ...                 ...
# 16913|RAB12        5.732470             4.598915            5.641990
# 7354|SS18L1        5.487408             5.035131            4.497590
# 9368|EIF4EBP2      7.249967             6.737142            7.389799
# 15126|FAM207A      4.534697             5.776378            5.785700
# 13297|DHX32        3.881621             4.822060            5.007943
# 5038|KIFAP3        6.844960             4.255027            4.393018
# 19470|FAM122C      2.664818             2.645279            1.921811
# 15241|GADD45GIP1   6.111335             6.227301            6.687523
# 5297|MAML1         4.716394             4.323347            4.957382
# 14253|NEIL1        4.301323             2.955541            2.912791
# 13297|DHX32               3.770809        4.186273            3.685561
# 5038|KIFAP3               3.417262        3.382723            5.442877
# 19470|FAM122C             2.831452        1.924994            2.091118
# 15241|GADD45GIP1          4.799517        7.093713            7.068784
# 5297|MAML1                5.290313        3.310260            3.523129
# 14253|NEIL1               2.241755        2.092283            3.461239
# 2771|ARSB                 6.523020        5.555346            3.837135
# 6397|PPP6R2               6.123518        4.727086            5.908870
# 13813|RNF217              0.943593        2.463547            4.184189
# 12466|RLIM                5.814767        5.350663            3.335554
# 9388|ERV3-1               2.288713        2.944794            3.585630
# 13259|PCBP2               9.923624       10.066857            9.606706
# 16669|FAM134C             4.705184        3.296112            4.198067
# 5222|LRP5                 0.996797        4.097304            6.074907
# 16262|CWF19L2             3.513424        3.489078            3.338449
# 10597|CASP2               5.769401        5.690555            5.434005
# 98|CHD4                   6.037007        6.807920            6.161342
# 13611|PTCH1               2.207588        0.378939            3.568469
# 12825|ZRANB1              5.038945        4.825619            5.524686
# 6178|PGM2                 4.025949        5.271188            3.411885
# 7875|UPF1                 3.969510        3.442479            4.457668
# 30125|POLR2J2             2.884493        1.721620            4.270467
# 13299|ZNF701              3.289376        1.327968            1.015263
# 15110|ZNF775              3.639950        2.354260            4.329167
# 14784|ANKRD27             4.590385        6.246659            4.424747
# 10238|TCTA                3.182210        3.233571            4.535649
#
#                   Hemat System3_log
# target gene
# 14266|CENPU                4.350937
# 13331|PEX14                4.315921
# 6630|RAD52                 3.566410
# 16802|CLYBL                3.409332
# 6645|RANBP1                6.690249
# 14535|TMEM258              7.256935
# 11931|HYAL1                5.577206
# 14256|SRGN                10.257102
# 7822|UBE2D1                4.379384
# 6543|PTCD2                 3.094954
# 3108|CAMKK2                3.749380
# 11649|GRAMD4               2.986377
# 3387|CLCN2                 3.396889
# 10214|TAF5                 1.541287
# 10390|ZNF146               4.596697
# 13447|POLK                 4.152115
# 12237|SNX24                2.815756
# 3948|EIF1B                 5.794260
# 2912|BCAR3                 2.685427
# 5875|NUP58                 4.925464
# 15466|FNIP1                2.929962
# 9404|FER                   2.138775
# 700|CD74                  11.140400
# 13332|CAND1                6.002880
# 2747|ARHGAP5               5.098733
# 10874|APBA3                3.958017
# 2612|ALAD                  7.856261
# 11326|ZNF274               4.010804
# 17847|ATP9B                2.605576
# 7689|TOMM22                5.311676
# ...                             ...
# 16913|RAB12                4.564201
# 7354|SS18L1                3.038019
# 9368|EIF4EBP2              6.731041
# 15126|FAM207A              4.774041
# 13297|DHX32                3.186332
# 5038|KIFAP3                4.805243
# 19470|FAM122C              2.443087
# 15241|GADD45GIP1           6.881876
# 5297|MAML1                 3.933927
# 14253|NEIL1                3.589916
# 2771|ARSB                  4.580821
# 6397|PPP6R2                6.317842
# 13813|RNF217               3.840403
# 12466|RLIM                 3.332576
# 9388|ERV3-1                2.502957
# 13259|PCBP2                9.786728
# 16669|FAM134C              4.710474
# 5222|LRP5                  4.634281
# 16262|CWF19L2              3.145505
# 10597|CASP2                5.739354
# 98|CHD4                    6.239819
# 13611|PTCH1                3.298284
# 12825|ZRANB1               5.172920
# 6178|PGM2                  3.625054
# 7875|UPF1                  4.614689
# 30125|POLR2J2              3.553479
# 13299|ZNF701               1.154847
# 15110|ZNF775               3.444430
# 14784|ANKRD27              4.249937
# 10238|TCTA                 4.269057
#
# [9840 rows x 10 columns]

# %%
leeza_0=leeza[(leeza != 0).all(1)]

# %%
f, axes = plt.subplots(1, 2,figsize=(20,10))
sns.kdeplot(data=data_log_0['Brain_log'],data2=data_log_0['Univ DriverMap_log'],ax=axes[0])
sns.kdeplot(data=data_log_0['Univ Stratagene_log'],data2=data_log_0['Univ Clontech_log'],color='skyblue',ax=axes[1])
plt.tight_layout()

# %%
# Another cool way to show log vs log
f, axes = plt.subplots(1, 2,figsize=(20,10))
sns.kdeplot(data=data_log['Brain_log'],data2=leeza['Brain'],ax=axes[0])
sns.kdeplot(data=data_log['Univ Stratagene_log'],data2=leeza['Univ Stratagene'],color='skyblue',ax=axes[1])
plt.tight_layout()

# %% [markdown]
# Next step would be to separate genes into bins for low/medium/high expression levels (figure out thresholds here) and then compare DM vs RS for each bin

# %%
data_log.head()

# To figure out bins, I looked up global max and min
print(f'Max: {data_log.max()}')
print(f'Min: {data_log.min()}')
# Out:
# Max: Brain_log              13.903312
# Univ Stratagene_log    14.583315
# Univ DriverMap_log     14.943352
# Univ Clontech_log      16.085180
# Univ BioChain_log      16.124078
# Univ Rare_log          15.296279
# WB-Activated_log       14.428116
# WB-Disease_log         15.530854
# Univ ImmuneT10_log     14.854120
# Hemat System3_log      14.756254
# dtype: float64
# Min: Brain_log              0.0
# Univ Stratagene_log    0.0
# Univ DriverMap_log     0.0
# Univ Clontech_log      0.0
# Univ BioChain_log      0.0
# Univ Rare_log          0.0
# WB-Activated_log       0.0
# WB-Disease_log         0.0
# Univ ImmuneT10_log     0.0
# Hemat System3_log      0.0
# dtype: float64

# %%
bins=[-1,0,5,10,20]
labels=['very low','low','medium','high']

def bin_logs(df):
    bin_data={}
    bin_group={}
    for i in list(df.columns):
        bin_data[i]=pd.cut(df[i],bins,labels=labels)
    bin_dataf=pd.DataFrame.from_dict(bin_data)
    for j in list(bin_dataf.columns):
        gr_count=bin_dataf.groupby(j)[j].count()
        bin_group[j]=gr_count
    final_d=pd.DataFrame.from_dict(bin_group)
    
    return final_d

# %%
binned_data=bin_logs(data_log)

# %%
binned_data
# Out:
#           Brain_log  Univ Stratagene_log  Univ DriverMap_log  \
# very low       3973                 4418                4832
# low            8496                 9253                8670
# medium         6450                 5186                5362
# high             70                  132                 125
#
#           Univ Clontech_log  Univ BioChain_log  Univ Rare_log  \
# very low               2393               4693           2636
# low                   10311              10455          10264
# medium                 6230               3728           5987
# high                     55                113            102
#
#           WB-Activated_log  WB-Disease_log  Univ ImmuneT10_log  \
# very low              6585            6406                2998
# low                   7830            8602               11192
# medium                4435            3833                4665
# high                   139             148                 134
#
#           Hemat System3_log
# very low               3841
# low                   10466
# medium                 4544
# high                    138

# %%
sns.heatmap(binned_data,cmap='YlGnBu')

# %% [markdown]
# TPM per gene per sample plot. Do regression Plot: Bar plot + regressions. I DON'T REMEMBER WHAT WE WANTED TO DO WITH THIS!

# %%
data_tpm=data_m.iloc[:,0:10]
data_tpm.head()
# Out:
#                  Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# target gene
# 14266|CENPU   2.153935        42.743575       51.583525      18.622583
# 13331|PEX14  37.341275        15.845198       15.942073      51.209025
# 6630|RAD52   10.436083        21.691725       13.252975       7.072937
# 16802|CLYBL  11.338755         8.822482        4.750612      20.617875
# 6645|RANBP1  65.908950       346.465250      226.077000     127.275900
#
#              Univ BioChain   Univ Rare  WB-Activated  WB-Disease  \
# target gene
# 14266|CENPU       3.504800   58.203800      1.938013   64.565900
# 13331|PEX14      17.724160   23.905800     20.258400   22.871142
# 6630|RAD52        5.070735    7.610290     11.173897    4.872158
# 16802|CLYBL      26.773325    9.021778      4.565878   13.185607
# 6645|RANBP1      48.031900  102.964925     89.185500  171.035500
#
#              Univ ImmuneT10  Hemat System3
# target gene
# 14266|CENPU        7.413818      20.406225
# 13331|PEX14       21.287950      19.916900
# 6630|RAD52        11.987092      11.846675
# 16802|CLYBL        7.269315      10.624565
# 6645|RANBP1       75.948850     103.267950

# %%
leeza.head()
# Out:
#                 Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# 14266|CENPU  0.000000         5.429904        6.139740       4.420557
# 13331|PEX14  4.790350         4.643897        4.115940       4.691986
# 6630|RAD52   2.398919         2.805206        1.714127       2.295414
# 16802|CLYBL  4.078499         3.836106        2.301154       4.924432
# 6645|RANBP1  5.523496         7.772070        7.165520       6.359249
#
#              Univ BioChain  Univ Rare  WB-Activated  WB-Disease  \
# 14266|CENPU       0.192889   5.559556      0.523030    6.599373
# 13331|PEX14       3.635987   4.176331      3.395131    4.872642
# 6630|RAD52        0.622256   2.421525      0.798971    2.298957
# 16802|CLYBL       4.855118   3.956094      2.858069    4.201626
# 6645|RANBP1       4.952082   6.135865      5.686526    7.072577
#
#              Univ ImmuneT10  Hemat System3  NegC_B67
# 14266|CENPU        4.137905       4.556601  0.000000
# 13331|PEX14        4.254556       3.816262  0.000000
# 6630|RAD52         1.872261       2.101035  0.000000
# 16802|CLYBL        3.520422       3.653679  5.107479
# 6645|RANBP1        6.162704       6.307844  0.000000

# %%
leeza_bin=bin_logs(leeza)
leeza_bin=leeza_bin
leeza_bin.head()
# Out:
#           Brain  Univ Stratagene  Univ DriverMap  Univ Clontech  \
# NegC_B67
# very low   4554             4370            5439           2516
# low        8807             9396            8505          10688
# medium     5547             5114            4930           5697
# high         81              109             115             88
#
#           Univ BioChain  Univ Rare  WB-Activated  WB-Disease  Univ ImmuneT10  \
# NegC_B67
# very low           5909       2840          7029        6485            3511
# low                9829      10618          8026        7586           10610
# medium             3136       5431          3812        4805            4767
# high                115        100           122         113             101
#
#           Hemat System3  NegC_B67
# NegC_B67
# very low           4606     11042
# low               10066      2338
# medium             4192      5596
# high                125        13

# %%
plt.figure(figsize=(25,15))
for i in range(10):
    title_font = {'fontname':'Arial', 'size':'20', 'color':'black', 'weight':'normal','verticalalignment':'bottom'}
    plt.subplot(2,5,i+1)
    plt.bar(x=binned_data.index, height=binned_data.iloc[:,i], alpha=0.7, color='red',label='RNAseq')
    plt.bar(x=binned_data.index, height=leeza_bin.iloc[:,i], alpha=0.5, color='blue',label='DM')
    plt.title(leeza_bin.columns[i],**title_font)
    plt.xlabel('level of expression')
    plt.ylabel('number of genes')
    plt.legend()
plt.tight_layout()

# %% [markdown]
# DM seems to be better at picking up genes of very low expression OR it doesn't pick up much genes so there are a bunch of zeros?

# %%
def find_highs(df):
    high_genes={}
    samples=list(df.columns)
    for column in samples:
        sample_cut=pd.cut(df[column],bins,labels=labels)
        sample_cut=sample_cut[sample_cut=='high']
        high_genes[column]=sample_cut
    high_genes_df=pd.DataFrame.from_dict(high_genes)
    return high_genes_df

# %%
new_df=find_highs(data_log)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1db6e0a6fe8f> in <module>
# ----> 1 new_df=find_highs(data_log)
#
# NameError: name 'data_log' is not defined

# %%
new_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-58ad22e406d5> in <module>
# ----> 1 new_df.head()
#
# NameError: name 'new_df' is not defined

# %%
def find_nan(column):

# %%
data_log.loc['100523|MTRNR2L2','Brain_log']
data_log.loc['10057|RPL37','Brain_log']
# Out:
# 10.23547577239733

# %%
TEST=pd.cut(data_log['Brain_log'],bins,labels=labels)
TEST2=data_log.iloc[:,0]
TEST2=TEST2.rename('Brain')
TEST3=pd.concat([TEST,TEST2],axis=1)
TEST3=TEST3.reset_index()
TEST3g=TEST3.groupby(['Brain_log'])
TEST3g['target gene'].unique()['high']
# Out:
# array(['11799|RPL13A', '7790|TUBB2B', '12681|MT3', '1613|CALM1',
#        '9034|UBC', '10676|SNURF', '1574|CALM2', '14335|SYT1',
#        '11543|FTH1', '11909|HSP90AB1', '14717|TUBA1B', '14722|TUBB3',
#        '6546|PTGDS', '10075|RPS21', '6806|RPL3', '7765|TSPAN7',
#        '13851|RPL9', '13846|RPL31', '19075|MTRNR2L10', '3995|ENO2',
#        '14802|VAMP2', '6128|PEBP1', '5347|MBP', '2015|CPE',
#        '11211|EEF1A1', '6294|PLP1', '8535|GFAP', '1580|GNAS',
#        '10057|RPL37', '10302|ATP1A1', '147|EIF4A2', '13848|RPL37A',
#        '3587|CST3', '10129|ALDOA', '10307|UCHL1', '20270|HIST1H4E',
#        '3858|DPYSL2', '10058|ACTB', '19025|CYCS', '20084|UBB',
#        '6817|RPS14', '8522|GAPDH', '100195|TUBA1C', '1959|SNAP25',
#        '8512|FTL', '100101|TUBB4A', '8053|YWHAH', '3925|EEF2', '746|CLU',
#        '19614|NRGN', '6807|RPL34', '4466|GLUL', '2629|ALDOC', '6508|PSAP',
#        '13876|RPS8', '100167|PBOV1', '2063|HSPA1A', '13892|RTN4',
#        '3100|CALM3', '3923|EEF1A2', '9237|CDR1', '9978|PTMA', '3379|CKB',
#        '18912|COX7C', '100049|SLC26A4', '100523|MTRNR2L2', '13842|RPL15',
#        '100205|ZNF486', '2817|ATP1A3', '3344|CHN1'], dtype=object)
