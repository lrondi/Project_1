# %% [markdown]
# # Using Ensembl REST API

# %%
import requests, sys
from pprint import pprint
import xmltodict
import re
import numpy as np

# %%
# This function is performed to get list of available Homo Sapience tissue types from Ensembl
 
server = "http://grch37.rest.ensembl.org"
ext = "/eqtl/tissue/homo_sapiens?"
 
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
 
if not r.ok:
  r.raise_for_status()
  sys.exit()
 
tissue_dict = r.json() # total of 44 tissue types

pprint(tissue_dict)
# Out:
# {'Adipose_Subcutaneous': 1,
#  'Adipose_Visceral_Omentum': 1,
#  'Adrenal_Gland': 1,
#  'Artery_Aorta': 1,
#  'Artery_Coronary': 1,
#  'Artery_Tibial': 1,
#  'Brain_Anterior_cingulate_cortex_BA24': 1,
#  'Brain_Caudate_basal_ganglia': 1,
#  'Brain_Cerebellar_Hemisphere': 1,
#  'Brain_Cerebellum': 1,
#  'Brain_Cortex': 1,
#  'Brain_Frontal_Cortex_BA9': 1,
#  'Brain_Hippocampus': 1,
#  'Brain_Hypothalamus': 1,
#  'Brain_Nucleus_accumbens_basal_ganglia': 1,
#  'Brain_Putamen_basal_ganglia': 1,
#  'Breast_Mammary_Tissue': 1,
#  'Cells_EBV-transformed_lymphocytes': 1,
#  'Cells_Transformed_fibroblasts': 1,
#  'Colon_Sigmoid': 1,
#  'Colon_Transverse': 1,
#  'Esophagus_Gastroesophageal_Junction': 1,
#  'Esophagus_Mucosa': 1,
#  'Esophagus_Muscularis': 1,
#  'Heart_Atrial_Appendage': 1,
#  'Heart_Left_Ventricle': 1,
#  'Liver': 1,
#  'Lung': 1,
#  'Muscle_Skeletal': 1,
#  'Nerve_Tibial': 1,
#  'Ovary': 1,
#  'Pancreas': 1,
#  'Pituitary': 1,
#  'Prostate': 1,
#  'Skin_Not_Sun_Exposed_Suprapubic': 1,
#  'Skin_Sun_Exposed_Lower_leg': 1,
#  'Small_Intestine_Terminal_Ileum': 1,
#  'Spleen': 1,
#  'Stomach': 1,
#  'Testis': 1,
#  'Thyroid': 1,
#  'Uterus': 1,
#  'Vagina': 1,
#  'Whole_Blood': 1}

# %%
# convert tissue dictionary to tissue list
dlist = []
for i in tissue_dict.items():
    dlist.append(i)

tissue_list = []    
for i in range(len(dlist)):
    tissue_list.append(dlist[i][0])

# %%
# api for searching through Ensembl data base by gene, tissue, statistics.
# iterrating through expression quantitative trait loci (eQTLs), which is a locus 
# that explains a fraction of the genetic variance of a gene expression phenotype

gene = 'CENPU'
tissue = 'Adipose_Visceral_Omentum'
statistic = 'p-value'

server = "http://grch37.rest.ensembl.org"
ext = f"/eqtl/id/homo_sapiens/{gene}?;tissue={tissue};statistic={statistic}"
 
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
 
if not r.ok:
  r.raise_for_status()
  sys.exit()
 
tissue_gene_values_dict = r.json()
pprint(tissue_gene_values_dict)
# Out:
# [{'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.364956143163666,
#   'seq_region_end': '183734182',
#   'seq_region_name': '4',
#   'seq_region_start': '183734182',
#   'snp': 'rs6827588',
#   'value': 0.431562655592666},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0223668232762906,
#   'seq_region_end': '183734459',
#   'seq_region_name': '4',
#   'seq_region_start': '183734459',
#   'snp': 'rs72693655',
#   'value': 0.949802212099595},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.632929333624897,
#   'seq_region_end': '183734623',
#   'seq_region_name': '4',
#   'seq_region_start': '183734623',
#   'snp': 'rs73004729',
#   'value': 0.232847010465122},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.832744485960855,
#   'seq_region_end': '183734684',
#   'seq_region_name': '4',
#   'seq_region_start': '183734684',
#   'snp': 'rs200656981',
#   'value': 0.146979076415116},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.749918626385846,
#   'seq_region_end': '183734684',
#   'seq_region_name': '4',
#   'seq_region_start': '183734684',
#   'snp': 'rs66772140',
#   'value': 0.17786126368841},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.682518766222813,
#   'seq_region_end': '183735685',
#   'seq_region_name': '4',
#   'seq_region_start': '183735685',
#   'snp': 'rs190357213',
#   'value': 0.207721396550433},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.073550066396869,
#   'seq_region_end': '183736305',
#   'seq_region_name': '4',
#   'seq_region_start': '183736305',
#   'snp': 'rs182191360',
#   'value': 0.844208914089585},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 1.21070689687802,
#   'seq_region_end': '183737676',
#   'seq_region_name': '4',
#   'seq_region_start': '183737676',
#   'snp': 'rs186680774',
#   'value': 0.0615592192564037},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0755586511301596,
#   'seq_region_end': '183737797',
#   'seq_region_name': '4',
#   'seq_region_start': '183737798',
#   'snp': 'rs201881455',
#   'value': 0.840313515753482},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0011804448738634,
#   'seq_region_end': '183738167',
#   'seq_region_name': '4',
#   'seq_region_start': '183738167',
#   'snp': 'rs36040879',
#   'value': 0.997285615851016},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.116448274773144,
#   'seq_region_end': '183738180',
#   'seq_region_name': '4',
#   'seq_region_start': '183738180',
#   'snp': 'rs35791833',
#   'value': 0.764806772829143},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.11671499299202,
#   'seq_region_end': '183738191',
#   'seq_region_name': '4',
#   'seq_region_start': '183738191',
#   'snp': 'rs35036196',
#   'value': 0.764337217532345},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.118695900239809,
#   'seq_region_end': '183738294',
#   'seq_region_name': '4',
#   'seq_region_start': '183738294',
#   'snp': 'rs13132455',
#   'value': 0.760858855679276},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.11890402346322,
#   'seq_region_end': '183738322',
#   'seq_region_name': '4',
#   'seq_region_start': '183738322',
#   'snp': 'rs13132298',
#   'value': 0.760494323161985},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0354066967606065,
#   'seq_region_end': '183738343',
#   'seq_region_name': '4',
#   'seq_region_start': '183738344',
#   'snp': 'rs35893181',
#   'value': 0.92170788594168},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.124823030888729,
#   'seq_region_end': '183738609',
#   'seq_region_name': '4',
#   'seq_region_start': '183738609',
#   'snp': 'rs13138460',
#   'value': 0.750199843318966},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.120571431272579,
#   'seq_region_end': '183738611',
#   'seq_region_name': '4',
#   'seq_region_start': '183738611',
#   'snp': 'rs13137953',
#   'value': 0.757580118428523},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.122452395720052,
#   'seq_region_end': '183738928',
#   'seq_region_name': '4',
#   'seq_region_start': '183738928',
#   'snp': 'rs35426606',
#   'value': 0.754306072996446},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.122452395720052,
#   'seq_region_end': '183738936',
#   'seq_region_name': '4',
#   'seq_region_start': '183738936',
#   'snp': 'rs34892641',
#   'value': 0.754306072996446},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.417055053435139,
#   'seq_region_end': '183739133',
#   'seq_region_name': '4',
#   'seq_region_start': '183739133',
#   'snp': 'rs80193237',
#   'value': 0.382776217530127},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.123709377801156,
#   'seq_region_end': '183739148',
#   'seq_region_name': '4',
#   'seq_region_start': '183739148',
#   'snp': 'rs13139698',
#   'value': 0.752126035115084},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.222083954243956,
#   'seq_region_end': '183739378',
#   'seq_region_name': '4',
#   'seq_region_start': '183739378',
#   'snp': 'rs4132292',
#   'value': 0.599675140774765},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.236045112180529,
#   'seq_region_end': '183739523',
#   'seq_region_name': '4',
#   'seq_region_start': '183739524',
#   'snp': 'rs35739129',
#   'value': 0.580704093962869},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.229605878696904,
#   'seq_region_end': '183739656',
#   'seq_region_name': '4',
#   'seq_region_start': '183739656',
#   'snp': 'rs4132293',
#   'value': 0.5893782722445},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.256826074048914,
#   'seq_region_end': '183739719',
#   'seq_region_name': '4',
#   'seq_region_start': '183739716',
#   'snp': 'rs372402814',
#   'value': 0.553571758861463},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.143031237079112,
#   'seq_region_end': '183739906',
#   'seq_region_name': '4',
#   'seq_region_start': '183739906',
#   'snp': 'rs201587410',
#   'value': 0.71939723275391},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.232220926383016,
#   'seq_region_end': '183739969',
#   'seq_region_name': '4',
#   'seq_region_start': '183739969',
#   'snp': 'rs13121953',
#   'value': 0.585840070803761},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.231457448775002,
#   'seq_region_end': '183739984',
#   'seq_region_name': '4',
#   'seq_region_start': '183739984',
#   'snp': 'rs13146008',
#   'value': 0.586870867128038},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.119871762663572,
#   'seq_region_end': '183740103',
#   'seq_region_name': '4',
#   'seq_region_start': '183740103',
#   'snp': 'rs13146626',
#   'value': 0.75880159890044},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.356838418420876,
#   'seq_region_end': '183740282',
#   'seq_region_name': '4',
#   'seq_region_start': '183740282',
#   'snp': 'rs12504849',
#   'value': 0.439705179666561},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.28811074889567,
#   'seq_region_end': '183740304',
#   'seq_region_name': '4',
#   'seq_region_start': '183740304',
#   'snp': 'rs12504852',
#   'value': 0.515097273517023},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.234535951139184,
#   'seq_region_end': '183740312',
#   'seq_region_name': '4',
#   'seq_region_start': '183740312',
#   'snp': 'rs12508954',
#   'value': 0.582725534455301},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.223451834261289,
#   'seq_region_end': '183741046',
#   'seq_region_name': '4',
#   'seq_region_start': '183741046',
#   'snp': 'rs397880780',
#   'value': 0.597789339264674},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.222176324972954,
#   'seq_region_end': '183741184',
#   'seq_region_name': '4',
#   'seq_region_start': '183741184',
#   'snp': 'rs4485841',
#   'value': 0.599547608554366},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.220004351851092,
#   'seq_region_end': '183741438',
#   'seq_region_name': '4',
#   'seq_region_start': '183741438',
#   'snp': 'rs34148954',
#   'value': 0.602553548151787},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.108393362532656,
#   'seq_region_end': '183741665',
#   'seq_region_name': '4',
#   'seq_region_start': '183741665',
#   'snp': 'rs13108312',
#   'value': 0.779124098635429},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.217427094212775,
#   'seq_region_end': '183741728',
#   'seq_region_name': '4',
#   'seq_region_start': '183741728',
#   'snp': 'rs13109044',
#   'value': 0.606139945777684},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.218810538887636,
#   'seq_region_end': '183741833',
#   'seq_region_name': '4',
#   'seq_region_start': '183741833',
#   'snp': 'rs35302319',
#   'value': 0.604212159645483},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.220287864990434,
#   'seq_region_end': '183741991',
#   'seq_region_name': '4',
#   'seq_region_start': '183741991',
#   'snp': 'rs34108831',
#   'value': 0.602160321650716},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.219947851013245,
#   'seq_region_end': '183742017',
#   'seq_region_name': '4',
#   'seq_region_start': '183742017',
#   'snp': 'rs35825015',
#   'value': 0.602631944254919},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.628994862236754,
#   'seq_region_end': '183742032',
#   'seq_region_name': '4',
#   'seq_region_start': '183742032',
#   'snp': 'rs62342178',
#   'value': 0.234966061749104},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.209998192765734,
#   'seq_region_end': '183742110',
#   'seq_region_name': '4',
#   'seq_region_start': '183742107',
#   'snp': 'rs70959144',
#   'value': 0.616597567710187},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.212733350715451,
#   'seq_region_end': '183742279',
#   'seq_region_name': '4',
#   'seq_region_start': '183742279',
#   'snp': 'rs67950584',
#   'value': 0.61272647969576},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.211880834162677,
#   'seq_region_end': '183742372',
#   'seq_region_name': '4',
#   'seq_region_start': '183742372',
#   'snp': 'rs66674592',
#   'value': 0.61393043810967},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.824394413150347,
#   'seq_region_end': '183742582',
#   'seq_region_name': '4',
#   'seq_region_start': '183742582',
#   'snp': 'rs112889504',
#   'value': 0.149832348522676},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.458685587580299,
#   'seq_region_end': '183742644',
#   'seq_region_name': '4',
#   'seq_region_start': '183742644',
#   'snp': 'rs7693830',
#   'value': 0.347787855289361},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.208393559039208,
#   'seq_region_end': '183742763',
#   'seq_region_name': '4',
#   'seq_region_start': '183742763',
#   'snp': 'rs7694501',
#   'value': 0.618879989873643},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.454765538403587,
#   'seq_region_end': '183742774',
#   'seq_region_name': '4',
#   'seq_region_start': '183742774',
#   'snp': 'rs6852842',
#   'value': 0.350941284710742},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.319682800186764,
#   'seq_region_end': '183742923',
#   'seq_region_name': '4',
#   'seq_region_start': '183742924',
#   'snp': 'rs70959145',
#   'value': 0.478979801654297},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0435353009146715,
#   'seq_region_end': '183743104',
#   'seq_region_name': '4',
#   'seq_region_start': '183743104',
#   'snp': 'rs4317243',
#   'value': 0.904616904448235},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.322065769263749,
#   'seq_region_end': '183743126',
#   'seq_region_name': '4',
#   'seq_region_start': '183743126',
#   'snp': 'rs4561964',
#   'value': 0.47635884188068},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.324358931735103,
#   'seq_region_end': '183743204',
#   'seq_region_name': '4',
#   'seq_region_start': '183743204',
#   'snp': 'rs4348138',
#   'value': 0.473850199999433},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.629366228420231,
#   'seq_region_end': '183743221',
#   'seq_region_name': '4',
#   'seq_region_start': '183743221',
#   'snp': 'rs4269218',
#   'value': 0.234765227622914},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.334508368890329,
#   'seq_region_end': '183743249',
#   'seq_region_name': '4',
#   'seq_region_start': '183743249',
#   'snp': 'rs4269219',
#   'value': 0.462904743479239},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.73442812501896,
#   'seq_region_end': '183743259',
#   'seq_region_name': '4',
#   'seq_region_start': '183743259',
#   'snp': 'rs4288048',
#   'value': 0.184319750971017},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.337567009699057,
#   'seq_region_end': '183743319',
#   'seq_region_name': '4',
#   'seq_region_start': '183743319',
#   'snp': 'rs4495079',
#   'value': 0.459656060181725},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.336697750686082,
#   'seq_region_end': '183743333',
#   'seq_region_name': '4',
#   'seq_region_start': '183743333',
#   'snp': 'rs13149650',
#   'value': 0.460577002825873},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.157581205448572,
#   'seq_region_end': '183743378',
#   'seq_region_name': '4',
#   'seq_region_start': '183743378',
#   'snp': 'rs115445061',
#   'value': 0.695694859805191},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0955137195167089,
#   'seq_region_end': '183743390',
#   'seq_region_name': '4',
#   'seq_region_start': '183743390',
#   'snp': 'rs13122861',
#   'value': 0.802576206805145},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.322076243145804,
#   'seq_region_end': '183743494',
#   'seq_region_name': '4',
#   'seq_region_start': '183743495',
#   'snp': 'rs146811316',
#   'value': 0.476347353670789},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.438588441543753,
#   'seq_region_end': '183743500',
#   'seq_region_name': '4',
#   'seq_region_start': '183743501',
#   'snp': 'rs35712801',
#   'value': 0.364260063072937},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.337252204942564,
#   'seq_region_end': '183743505',
#   'seq_region_name': '4',
#   'seq_region_start': '183743505',
#   'snp': 'rs13122554',
#   'value': 0.45998936943952},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.745824896236808,
#   'seq_region_end': '183743531',
#   'seq_region_name': '4',
#   'seq_region_start': '183743531',
#   'snp': 'rs62342179',
#   'value': 0.17954573937418},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.340659412696104,
#   'seq_region_end': '183743677',
#   'seq_region_name': '4',
#   'seq_region_start': '183743677',
#   'snp': 'rs13123170',
#   'value': 0.456394694623669},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.284208764213705,
#   'seq_region_end': '183743995',
#   'seq_region_name': '4',
#   'seq_region_start': '183743995',
#   'snp': 'rs13123876',
#   'value': 0.519746095895531},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.349397971489555,
#   'seq_region_end': '183744079',
#   'seq_region_name': '4',
#   'seq_region_start': '183744079',
#   'snp': 'rs13123914',
#   'value': 0.44730322409148},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.350180040276094,
#   'seq_region_end': '183744162',
#   'seq_region_name': '4',
#   'seq_region_start': '183744162',
#   'snp': 'rs62342180',
#   'value': 0.446498454247267},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.226976384426263,
#   'seq_region_end': '183744256',
#   'seq_region_name': '4',
#   'seq_region_start': '183744256',
#   'snp': 'rs58426973',
#   'value': 0.592957566878747},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.390511250369543,
#   'seq_region_end': '183744303',
#   'seq_region_name': '4',
#   'seq_region_start': '183744303',
#   'snp': 'rs56361485',
#   'value': 0.406900992929626},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.290085310683246,
#   'seq_region_end': '183744398',
#   'seq_region_name': '4',
#   'seq_region_start': '183744398',
#   'snp': 'rs55783005',
#   'value': 0.51276064990444},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.354654779036036,
#   'seq_region_end': '183744621',
#   'seq_region_name': '4',
#   'seq_region_start': '183744621',
#   'snp': 'rs59967714',
#   'value': 0.441921591530786},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.287207769811797,
#   'seq_region_end': '183744681',
#   'seq_region_name': '4',
#   'seq_region_start': '183744681',
#   'snp': 'rs61242366',
#   'value': 0.516169370807057},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.284429203644797,
#   'seq_region_end': '183744856',
#   'seq_region_name': '4',
#   'seq_region_start': '183744856',
#   'snp': 'rs60350005',
#   'value': 0.519482349829235},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.439113932917154,
#   'seq_region_end': '183744875',
#   'seq_region_name': '4',
#   'seq_region_start': '183744875',
#   'snp': 'rs59843753',
#   'value': 0.363819579092171},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.172909054130056,
#   'seq_region_end': '183744959',
#   'seq_region_name': '4',
#   'seq_region_start': '183744959',
#   'snp': 'rs113304305',
#   'value': 0.671569471970902},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.81984105908283,
#   'seq_region_end': '183745176',
#   'seq_region_name': '4',
#   'seq_region_start': '183745176',
#   'snp': 'rs62342184',
#   'value': 0.151411527536755},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.47001076795037,
#   'seq_region_end': '183745369',
#   'seq_region_name': '4',
#   'seq_region_start': '183745369',
#   'snp': 'rs13112823',
#   'value': 0.338835754900006},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.170021544116156,
#   'seq_region_end': '183745521',
#   'seq_region_name': '4',
#   'seq_region_start': '183745521',
#   'snp': 'rs35890433',
#   'value': 0.676049437667036},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.460512479476421,
#   'seq_region_end': '183745529',
#   'seq_region_name': '4',
#   'seq_region_start': '183745529',
#   'snp': 'rs116399402',
#   'value': 0.346327932712625},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.473651509867583,
#   'seq_region_end': '183745713',
#   'seq_region_name': '4',
#   'seq_region_start': '183745713',
#   'snp': 'rs12503497',
#   'value': 0.336007127685168},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.474810199471621,
#   'seq_region_end': '183745823',
#   'seq_region_name': '4',
#   'seq_region_start': '183745823',
#   'snp': 'rs4583805',
#   'value': 0.335111861722513},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.225500333678182,
#   'seq_region_end': '183745854',
#   'seq_region_name': '4',
#   'seq_region_start': '183745854',
#   'snp': 'rs111395617',
#   'value': 0.594976299625182},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.819795371347157,
#   'seq_region_end': '183745862',
#   'seq_region_name': '4',
#   'seq_region_start': '183745862',
#   'snp': 'rs12503556',
#   'value': 0.15142745685204},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.223877421704279,
#   'seq_region_end': '183746027',
#   'seq_region_name': '4',
#   'seq_region_start': '183746027',
#   'snp': 'rs34082813',
#   'value': 0.597203821759521},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.380996768176091,
#   'seq_region_end': '183746380',
#   'seq_region_name': '4',
#   'seq_region_start': '183746380',
#   'snp': 'rs11736510',
#   'value': 0.415913705524957},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.475556250760881,
#   'seq_region_end': '183746399',
#   'seq_region_name': '4',
#   'seq_region_start': '183746399',
#   'snp': 'rs4861573',
#   'value': 0.334536685131868},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.075033660689159,
#   'seq_region_end': '183746416',
#   'seq_region_name': '4',
#   'seq_region_start': '183746416',
#   'snp': 'rs4449456',
#   'value': 0.841329930494783},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.177389293881357,
#   'seq_region_end': '183746596',
#   'seq_region_name': '4',
#   'seq_region_start': '183746596',
#   'snp': 'rs34328120',
#   'value': 0.664677084321886},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.888967798993163,
#   'seq_region_end': '183746607',
#   'seq_region_name': '4',
#   'seq_region_start': '183746607',
#   'snp': 'rs4862244',
#   'value': 0.129131501533686},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.355149270696353,
#   'seq_region_end': '183746622',
#   'seq_region_name': '4',
#   'seq_region_start': '183746622',
#   'snp': 'rs4862245',
#   'value': 0.441418701925521},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.887817272144483,
#   'seq_region_end': '183746675',
#   'seq_region_name': '4',
#   'seq_region_start': '183746675',
#   'snp': 'rs4862246',
#   'value': 0.129474048430824},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.80600738106914,
#   'seq_region_end': '183746899',
#   'seq_region_name': '4',
#   'seq_region_start': '183746899',
#   'snp': 'rs56929271',
#   'value': 0.156312107632878},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.520668078775492,
#   'seq_region_end': '183746955',
#   'seq_region_name': '4',
#   'seq_region_start': '183746955',
#   'snp': 'rs62342186',
#   'value': 0.301530967518174},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.142868255863418,
#   'seq_region_end': '183746966',
#   'seq_region_name': '4',
#   'seq_region_start': '183746966',
#   'snp': 'rs35998899',
#   'value': 0.719667257457305},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.214190755856526,
#   'seq_region_end': '183747002',
#   'seq_region_name': '4',
#   'seq_region_start': '183747002',
#   'snp': 'rs35620017',
#   'value': 0.610673738791756},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.550342629119549,
#   'seq_region_end': '183747100',
#   'seq_region_name': '4',
#   'seq_region_start': '183747100',
#   'snp': 'rs10009806',
#   'value': 0.281616029367115},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.819427358312409,
#   'seq_region_end': '183747364',
#   'seq_region_name': '4',
#   'seq_region_start': '183747364',
#   'snp': 'rs62342187',
#   'value': 0.151555828033488},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.494886053140357,
#   'seq_region_end': '183747803',
#   'seq_region_name': '4',
#   'seq_region_start': '183747803',
#   'snp': 'rs4130368',
#   'value': 0.319973452140244},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.819217501270848,
#   'seq_region_end': '183747968',
#   'seq_region_name': '4',
#   'seq_region_start': '183747968',
#   'snp': 'rs4862247',
#   'value': 0.151629079581886},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.819167823856682,
#   'seq_region_end': '183748076',
#   'seq_region_name': '4',
#   'seq_region_start': '183748076',
#   'snp': 'rs4862248',
#   'value': 0.151646424889567},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.818990045360969,
#   'seq_region_end': '183748428',
#   'seq_region_name': '4',
#   'seq_region_start': '183748428',
#   'snp': 'rs7698466',
#   'value': 0.151708514078137},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0131116124982304,
#   'seq_region_end': '183748684',
#   'seq_region_name': '4',
#   'seq_region_start': '183748684',
#   'snp': 'rs72693672',
#   'value': 0.9702605808761},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.815404109403013,
#   'seq_region_end': '183748715',
#   'seq_region_name': '4',
#   'seq_region_start': '183748715',
#   'snp': 'rs62342188',
#   'value': 0.152966345310347},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.750731300763262,
#   'seq_region_end': '183748894',
#   'seq_region_name': '4',
#   'seq_region_start': '183748894',
#   'snp': 'rs4460041',
#   'value': 0.177528751663477},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.818990045360969,
#   'seq_region_end': '183749109',
#   'seq_region_name': '4',
#   'seq_region_start': '183749109',
#   'snp': 'rs6858273',
#   'value': 0.151708514078137},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.489055728925865,
#   'seq_region_end': '183749128',
#   'seq_region_name': '4',
#   'seq_region_start': '183749128',
#   'snp': 'rs6552701',
#   'value': 0.324298000567213},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.604422469826004,
#   'seq_region_end': '183749195',
#   'seq_region_name': '4',
#   'seq_region_start': '183749195',
#   'snp': 'rs62342201',
#   'value': 0.248643740297487},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.148694104836355,
#   'seq_region_end': '183749236',
#   'seq_region_name': '4',
#   'seq_region_start': '183749236',
#   'snp': 'rs7699675',
#   'value': 0.710077734866608},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.148543685629072,
#   'seq_region_end': '183749446',
#   'seq_region_name': '4',
#   'seq_region_start': '183749444',
#   'snp': 'rs70959146',
#   'value': 0.710323715033158},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.634002479059349,
#   'seq_region_end': '183750095',
#   'seq_region_name': '4',
#   'seq_region_start': '183750095',
#   'snp': 'rs10025126',
#   'value': 0.232272353764401},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.622022443808755,
#   'seq_region_end': '183750114',
#   'seq_region_name': '4',
#   'seq_region_start': '183750114',
#   'snp': 'rs74859775',
#   'value': 0.238768788692898},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.206284898174158,
#   'seq_region_end': '183750140',
#   'seq_region_name': '4',
#   'seq_region_start': '183750140',
#   'snp': 'rs35300204',
#   'value': 0.621892188628512},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.206284898174158,
#   'seq_region_end': '183750147',
#   'seq_region_name': '4',
#   'seq_region_start': '183750147',
#   'snp': 'rs35253131',
#   'value': 0.621892188628512},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.206182321744321,
#   'seq_region_end': '183750417',
#   'seq_region_name': '4',
#   'seq_region_start': '183750417',
#   'snp': 'rs35456195',
#   'value': 0.62203909128832},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.454045051258664,
#   'seq_region_end': '183750681',
#   'seq_region_name': '4',
#   'seq_region_start': '183750681',
#   'snp': 'rs12510859',
#   'value': 0.35152397352366},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.782991007840525,
#   'seq_region_end': '183750835',
#   'seq_region_name': '4',
#   'seq_region_start': '183750835',
#   'snp': 'rs6822581',
#   'value': 0.164819651743112},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.818990045360969,
#   'seq_region_end': '183751210',
#   'seq_region_name': '4',
#   'seq_region_start': '183751210',
#   'snp': 'rs6848988',
#   'value': 0.151708514078137},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.495260911240256,
#   'seq_region_end': '183751273',
#   'seq_region_name': '4',
#   'seq_region_start': '183751273',
#   'snp': 'rs6849182',
#   'value': 0.319697388557802},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.818990045360969,
#   'seq_region_end': '183751463',
#   'seq_region_name': '4',
#   'seq_region_start': '183751464',
#   'snp': 'rs200181115',
#   'value': 0.151708514078137},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.833703003480806,
#   'seq_region_end': '183751464',
#   'seq_region_name': '4',
#   'seq_region_start': '183751465',
#   'snp': 'rs74281568',
#   'value': 0.146655041291766},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.818990045360969,
#   'seq_region_end': '183751772',
#   'seq_region_name': '4',
#   'seq_region_start': '183751772',
#   'snp': 'rs6829604',
#   'value': 0.151708514078137},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.819691037942691,
#   'seq_region_end': '183751951',
#   'seq_region_name': '4',
#   'seq_region_start': '183751951',
#   'snp': 'rs6830009',
#   'value': 0.151463839630673},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.494886053140357,
#   'seq_region_end': '183752115',
#   'seq_region_name': '4',
#   'seq_region_start': '183752115',
#   'snp': 'rs6552702',
#   'value': 0.319973452140244},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.285944661673166,
#   'seq_region_end': '183752643',
#   'seq_region_name': '4',
#   'seq_region_start': '183752643',
#   'snp': 'rs72693674',
#   'value': 0.517672790239709},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.379130359649772,
#   'seq_region_end': '183753115',
#   'seq_region_name': '4',
#   'seq_region_start': '183753115',
#   'snp': 'rs58969632',
#   'value': 0.417704967755678},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 1.0820701372555,
#   'seq_region_end': '183753281',
#   'seq_region_name': '4',
#   'seq_region_start': '183753281',
#   'snp': 'rs62342202',
#   'value': 0.082780846433388},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 1.08291713948128,
#   'seq_region_end': '183753389',
#   'seq_region_name': '4',
#   'seq_region_start': '183753389',
#   'snp': 'rs66763094',
#   'value': 0.0826195567197866},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0828746587309712,
#   'seq_region_end': '183754495',
#   'seq_region_name': '4',
#   'seq_region_start': '183754495',
#   'snp': 'rs6552703',
#   'value': 0.826276385918},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.441157804897471,
#   'seq_region_end': '183754499',
#   'seq_region_name': '4',
#   'seq_region_start': '183754499',
#   'snp': 'rs28706440',
#   'value': 0.362111397999511},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.764295716112366,
#   'seq_region_end': '183754582',
#   'seq_region_name': '4',
#   'seq_region_start': '183754582',
#   'snp': 'rs185284034',
#   'value': 0.17206965339244},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.371530054855403,
#   'seq_region_end': '183754684',
#   'seq_region_name': '4',
#   'seq_region_start': '183754684',
#   'snp': 'rs112406735',
#   'value': 0.425079288658262},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.232565292297665,
#   'seq_region_end': '183754723',
#   'seq_region_name': '4',
#   'seq_region_start': '183754723',
#   'snp': 'rs13113027',
#   'value': 0.585375723691379},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.222546323116515,
#   'seq_region_end': '183754824',
#   'seq_region_name': '4',
#   'seq_region_start': '183754824',
#   'snp': 'rs13113415',
#   'value': 0.599037040165194},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.00239237218850911,
#   'seq_region_end': '183754912',
#   'seq_region_name': '4',
#   'seq_region_start': '183754912',
#   'snp': 'rs6552704',
#   'value': 0.9945065042004},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.223442408928219,
#   'seq_region_end': '183754962',
#   'seq_region_name': '4',
#   'seq_region_start': '183754962',
#   'snp': 'rs36118703',
#   'value': 0.597802313007155},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.551688135939289,
#   'seq_region_end': '183754996',
#   'seq_region_name': '4',
#   'seq_region_start': '183754996',
#   'snp': 'rs67131530',
#   'value': 0.280744892521204},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.266277323936983,
#   'seq_region_end': '183755109',
#   'seq_region_name': '4',
#   'seq_region_start': '183755109',
#   'snp': 'rs35661846',
#   'value': 0.541654899728976},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.553541951457,
#   'seq_region_end': '183755166',
#   'seq_region_name': '4',
#   'seq_region_start': '183755166',
#   'snp': 'rs62342204',
#   'value': 0.279549067908545},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.553847105296893,
#   'seq_region_end': '183755195',
#   'seq_region_name': '4',
#   'seq_region_start': '183755195',
#   'snp': 'rs62342205',
#   'value': 0.279352713792963},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.161800851299097,
#   'seq_region_end': '183755221',
#   'seq_region_name': '4',
#   'seq_region_start': '183755221',
#   'snp': 'rs35491745',
#   'value': 0.688968154972282},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.554112822043388,
#   'seq_region_end': '183755241',
#   'seq_region_name': '4',
#   'seq_region_start': '183755241',
#   'snp': 'rs62342206',
#   'value': 0.279181848184294},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.555021724745266,
#   'seq_region_end': '183755336',
#   'seq_region_name': '4',
#   'seq_region_start': '183755336',
#   'snp': 'rs73004771',
#   'value': 0.278598180176852},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.634087757186884,
#   'seq_region_end': '183755491',
#   'seq_region_name': '4',
#   'seq_region_start': '183755491',
#   'snp': 'rs12641815',
#   'value': 0.23222674920889},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.326479191246023,
#   'seq_region_end': '183756022',
#   'seq_region_name': '4',
#   'seq_region_start': '183756022',
#   'snp': 'rs6857008',
#   'value': 0.471542464246259},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.156696530475686,
#   'seq_region_end': '183756077',
#   'seq_region_name': '4',
#   'seq_region_start': '183756077',
#   'snp': 'rs6857724',
#   'value': 0.697113462032043},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0216925463955769,
#   'seq_region_end': '183756095',
#   'seq_region_name': '4',
#   'seq_region_start': '183756095',
#   'snp': 'rs72693676',
#   'value': 0.951278001261296},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.5608334592913,
#   'seq_region_end': '183756124',
#   'seq_region_name': '4',
#   'seq_region_start': '183756124',
#   'snp': 'rs6857412',
#   'value': 0.2748948101554},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.561136312700786,
#   'seq_region_end': '183756169',
#   'seq_region_name': '4',
#   'seq_region_start': '183756169',
#   'snp': 'rs6857935',
#   'value': 0.274703180252843},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.164956846474643,
#   'seq_region_end': '183756171',
#   'seq_region_name': '4',
#   'seq_region_start': '183756171',
#   'snp': 'rs62342207',
#   'value': 0.683979607308959},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.418194001857577,
#   'seq_region_end': '183756580',
#   'seq_region_name': '4',
#   'seq_region_start': '183756580',
#   'snp': 'rs28645601',
#   'value': 0.381773692226675},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.292367558093784,
#   'seq_region_end': '183756585',
#   'seq_region_name': '4',
#   'seq_region_start': '183756585',
#   'snp': 'rs188078981',
#   'value': 0.510073125126128},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.539333917017663,
#   'seq_region_end': '183757364',
#   'seq_region_name': '4',
#   'seq_region_start': '183757364',
#   'snp': 'rs72693677',
#   'value': 0.28884581727544},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0104390687443013,
#   'seq_region_end': '183758207',
#   'seq_region_name': '4',
#   'seq_region_start': '183758207',
#   'snp': 'rs6552705',
#   'value': 0.976249740076277},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.168654496163477,
#   'seq_region_end': '183758725',
#   'seq_region_name': '4',
#   'seq_region_start': '183758725',
#   'snp': 'rs79338501',
#   'value': 0.678180821153725},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.00589618664738431,
#   'seq_region_end': '183759056',
#   'seq_region_name': '4',
#   'seq_region_start': '183759056',
#   'snp': 'rs35304118',
#   'value': 0.986515273150383},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0844900609978685,
#   'seq_region_end': '183759316',
#   'seq_region_name': '4',
#   'seq_region_start': '183759316',
#   'snp': 'rs4861576',
#   'value': 0.823208676164136},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.462699465689546,
#   'seq_region_end': '183759539',
#   'seq_region_name': '4',
#   'seq_region_start': '183759539',
#   'snp': 'rs72693678',
#   'value': 0.344588305389442},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.260826833348518,
#   'seq_region_end': '183759753',
#   'seq_region_name': '4',
#   'seq_region_start': '183759753',
#   'snp': 'rs7689752',
#   'value': 0.548495623506183},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.399106762340607,
#   'seq_region_end': '183759868',
#   'seq_region_name': '4',
#   'seq_region_start': '183759868',
#   'snp': 'rs111552159',
#   'value': 0.398926822376159},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.11777865850223,
#   'seq_region_end': '183759910',
#   'seq_region_name': '4',
#   'seq_region_start': '183759910',
#   'snp': 'rs4590088',
#   'value': 0.762467508402165},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0206609156007943,
#   'seq_region_end': '183759944',
#   'seq_region_name': '4',
#   'seq_region_start': '183759944',
#   'snp': 'rs62342209',
#   'value': 0.95354036982451},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.00574805356732205,
#   'seq_region_end': '183760197',
#   'seq_region_name': '4',
#   'seq_region_start': '183760197',
#   'snp': 'rs62342210',
#   'value': 0.986851820072989},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.194252086355121,
#   'seq_region_end': '183760683',
#   'seq_region_name': '4',
#   'seq_region_start': '183760683',
#   'snp': 'rs28655831',
#   'value': 0.639363608965752},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0932129960850592,
#   'seq_region_end': '183761261',
#   'seq_region_name': '4',
#   'seq_region_start': '183761261',
#   'snp': 'rs11728590',
#   'value': 0.806839225668145},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.512003937067449,
#   'seq_region_end': '183761358',
#   'seq_region_name': '4',
#   'seq_region_start': '183761358',
#   'snp': 'rs34427720',
#   'value': 0.307606892871809},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.67167764493245,
#   'seq_region_end': '183761787',
#   'seq_region_name': '4',
#   'seq_region_start': '183761787',
#   'snp': 'rs28689940',
#   'value': 0.212971924351078},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.198425371174127,
#   'seq_region_end': '183761955',
#   'seq_region_name': '4',
#   'seq_region_start': '183761955',
#   'snp': 'rs4241781',
#   'value': 0.633249169406413},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.085242046416882,
#   'seq_region_end': '183763194',
#   'seq_region_name': '4',
#   'seq_region_start': '183763194',
#   'snp': 'rs4861577',
#   'value': 0.82178451509752},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.189458087499941,
#   'seq_region_end': '183763741',
#   'seq_region_name': '4',
#   'seq_region_start': '183763741',
#   'snp': 'rs7669595',
#   'value': 0.646460379004238},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.246975872353022,
#   'seq_region_end': '183764276',
#   'seq_region_name': '4',
#   'seq_region_start': '183764276',
#   'snp': 'rs34295622',
#   'value': 0.566270747879548},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.18489380092097,
#   'seq_region_end': '183764644',
#   'seq_region_name': '4',
#   'seq_region_start': '183764644',
#   'snp': 'rs4862249',
#   'value': 0.653290283768569},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.505624921978209,
#   'seq_region_end': '183765066',
#   'seq_region_name': '4',
#   'seq_region_start': '183765066',
#   'snp': 'rs4862250',
#   'value': 0.312158437366548},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.214452515686722,
#   'seq_region_end': '183765186',
#   'seq_region_name': '4',
#   'seq_region_start': '183765186',
#   'snp': 'rs67764380',
#   'value': 0.61030578179987},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0203489725103615,
#   'seq_region_end': '183766112',
#   'seq_region_name': '4',
#   'seq_region_start': '183766112',
#   'snp': 'rs116472556',
#   'value': 0.954225520553887},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.318987337779289,
#   'seq_region_end': '183766280',
#   'seq_region_name': '4',
#   'seq_region_start': '183766280',
#   'snp': 'rs58015603',
#   'value': 0.479747435872577},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 1.09833931904143,
#   'seq_region_end': '183766491',
#   'seq_region_name': '4',
#   'seq_region_start': '183766491',
#   'snp': 'rs4862251',
#   'value': 0.0797371448770785},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 1.30118945418215,
#   'seq_region_end': '183766848',
#   'seq_region_name': '4',
#   'seq_region_start': '183766848',
#   'snp': 'rs10028767',
#   'value': 0.0499816450295293},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.866350966960147,
#   'seq_region_end': '183766945',
#   'seq_region_name': '4',
#   'seq_region_start': '183766945',
#   'snp': 'rs55965833',
#   'value': 0.136034490086149},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.663201311661847,
#   'seq_region_end': '183766946',
#   'seq_region_name': '4',
#   'seq_region_start': '183766946',
#   'snp': 'rs189172586',
#   'value': 0.217169428435874},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.250280101758115,
#   'seq_region_end': '183766959',
#   'seq_region_name': '4',
#   'seq_region_start': '183766959',
#   'snp': 'rs55944525',
#   'value': 0.561978755512981},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.259476694651644,
#   'seq_region_end': '183766968',
#   'seq_region_name': '4',
#   'seq_region_start': '183766968',
#   'snp': 'rs55879342',
#   'value': 0.550203445037148},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.189749836020929,
#   'seq_region_end': '183766990',
#   'seq_region_name': '4',
#   'seq_region_start': '183766990',
#   'snp': 'rs28549340',
#   'value': 0.646026248404523},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.703176523418014,
#   'seq_region_end': '183767025',
#   'seq_region_name': '4',
#   'seq_region_start': '183767025',
#   'snp': 'rs56088128',
#   'value': 0.19807217776137},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.199559810950899,
#   'seq_region_end': '183767390',
#   'seq_region_name': '4',
#   'seq_region_start': '183767390',
#   'snp': 'rs6831550',
#   'value': 0.631597189856415},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.867791769398946,
#   'seq_region_end': '183767392',
#   'seq_region_name': '4',
#   'seq_region_start': '183767392',
#   'snp': 'rs56058176',
#   'value': 0.135583933902416},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.53617630856437,
#   'seq_region_end': '183767747',
#   'seq_region_name': '4',
#   'seq_region_start': '183767747',
#   'snp': 'rs34648331',
#   'value': 0.290953570723989},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.451769350299967,
#   'seq_region_end': '183767771',
#   'seq_region_name': '4',
#   'seq_region_start': '183767771',
#   'snp': 'rs150365830',
#   'value': 0.353370791857481},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 1.00992255743644,
#   'seq_region_end': '183768037',
#   'seq_region_name': '4',
#   'seq_region_start': '183768037',
#   'snp': 'rs4394042',
#   'value': 0.0977411495570581},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.021258786384235,
#   'seq_region_end': '183768256',
#   'seq_region_name': '4',
#   'seq_region_start': '183768256',
#   'snp': 'rs4538533',
#   'value': 0.952228583186036},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.021258786384235,
#   'seq_region_end': '183768264',
#   'seq_region_name': '4',
#   'seq_region_start': '183768264',
#   'snp': 'rs4568278',
#   'value': 0.952228583186036},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.199667374095213,
#   'seq_region_end': '183768532',
#   'seq_region_name': '4',
#   'seq_region_start': '183768532',
#   'snp': 'rs9990700',
#   'value': 0.63144077947091},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.219085191787829,
#   'seq_region_end': '183768609',
#   'seq_region_name': '4',
#   'seq_region_start': '183768609',
#   'snp': 'rs62342212',
#   'value': 0.603830169622519},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 1.1566891412348,
#   'seq_region_end': '183768630',
#   'seq_region_name': '4',
#   'seq_region_start': '183768630',
#   'snp': 'rs67201023',
#   'value': 0.0697125323069505},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.213357748578025,
#   'seq_region_end': '183769645',
#   'seq_region_name': '4',
#   'seq_region_start': '183769645',
#   'snp': 'rs62342213',
#   'value': 0.611846177907314},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.199390308555165,
#   'seq_region_end': '183770403',
#   'seq_region_name': '4',
#   'seq_region_start': '183770403',
#   'snp': 'rs4862252',
#   'value': 0.631843746365608},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.188415112539226,
#   'seq_region_end': '183770432',
#   'seq_region_name': '4',
#   'seq_region_start': '183770432',
#   'snp': 'rs4861578',
#   'value': 0.648014744242793},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.0256172473200204,
#   'seq_region_end': '183770887',
#   'seq_region_name': '4',
#   'seq_region_start': '183770887',
#   'snp': 'rs59364695',
#   'value': 0.942720069144089},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.025252469846939,
#   'seq_region_end': '183770995',
#   'seq_region_name': '4',
#   'seq_region_start': '183770995',
#   'snp': 'rs60242819',
#   'value': 0.943512221746684},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.18101170109104,
#   'seq_region_end': '183771055',
#   'seq_region_name': '4',
#   'seq_region_start': '183771055',
#   'snp': 'rs56798100',
#   'value': 0.659156135520962},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 0.18101170109104,
#   'seq_region_end': '183771070',
#   'seq_region_name': '4',
#   'seq_region_start': '183771070',
#   'snp': 'rs58613332',
#   'value': 0.659156135520962},
#  {'display_consequence': 'intergenic_variant',
#   'minus_log10_p_value': 1.0470151431633,
#   'seq_region_end': '183771164',
#   'seq_region_name': '4',
#   'seq_region_start': '183771164',
#   'snp': 'rs60966615',
#   'value': 0.0897397503120305},
# ...
#   'value': 0.812979021113985},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.0675803341161174,
#   'seq_region_end': '185717967',
#   'seq_region_name': '4',
#   'seq_region_start': '185717967',
#   'snp': 'rs34643095',
#   'value': 0.855893377224838},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 1.01212429505615,
#   'seq_region_end': '185717992',
#   'seq_region_name': '4',
#   'seq_region_start': '185717992',
#   'snp': 'rs7694063',
#   'value': 0.0972468863411823},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.216012814782504,
#   'seq_region_end': '185718187',
#   'seq_region_name': '4',
#   'seq_region_start': '185718187',
#   'snp': 'rs7694583',
#   'value': 0.608117057226643},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.311218017087986,
#   'seq_region_end': '185718188',
#   'seq_region_name': '4',
#   'seq_region_start': '185718188',
#   'snp': 'rs80210472',
#   'value': 0.488407116004492},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.311133139380809,
#   'seq_region_end': '185718275',
#   'seq_region_name': '4',
#   'seq_region_start': '185718275',
#   'snp': 'rs79448898',
#   'value': 0.488502578712628},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.28830632345694,
#   'seq_region_end': '185718793',
#   'seq_region_name': '4',
#   'seq_region_start': '185718793',
#   'snp': 'rs28755896',
#   'value': 0.51486536349301},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.0570917036202948,
#   'seq_region_end': '185718896',
#   'seq_region_name': '4',
#   'seq_region_start': '185718896',
#   'snp': 'rs6836237',
#   'value': 0.876815657243902},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.936573478501953,
#   'seq_region_end': '185718925',
#   'seq_region_name': '4',
#   'seq_region_start': '185718925',
#   'snp': 'rs72702070',
#   'value': 0.115724822011919},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.29894439750395,
#   'seq_region_end': '185719085',
#   'seq_region_name': '4',
#   'seq_region_start': '185719086',
#   'snp': 'rs397933769',
#   'value': 0.502406908299433},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.1842675877458,
#   'seq_region_end': '185719315',
#   'seq_region_name': '4',
#   'seq_region_start': '185719315',
#   'snp': 'rs6837079',
#   'value': 0.654232948443241},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.0585698659327906,
#   'seq_region_end': '185719435',
#   'seq_region_name': '4',
#   'seq_region_start': '185719435',
#   'snp': 'rs4862565',
#   'value': 0.87383640524927},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.502647556441221,
#   'seq_region_end': '185719472',
#   'seq_region_name': '4',
#   'seq_region_start': '185719472',
#   'snp': 'rs6816948',
#   'value': 0.314305834935341},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.899570119024413,
#   'seq_region_end': '185719848',
#   'seq_region_name': '4',
#   'seq_region_start': '185719848',
#   'snp': 'rs4862566',
#   'value': 0.126017216034684},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.0193585686060652,
#   'seq_region_end': '185720059',
#   'seq_region_name': '4',
#   'seq_region_start': '185720059',
#   'snp': 'rs13131324',
#   'value': 0.956404104785736},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.154854286834638,
#   'seq_region_end': '185720386',
#   'seq_region_name': '4',
#   'seq_region_start': '185720386',
#   'snp': 'rs10017672',
#   'value': 0.700076844258526},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.261420483620632,
#   'seq_region_end': '185720409',
#   'seq_region_name': '4',
#   'seq_region_start': '185720409',
#   'snp': 'rs10017683',
#   'value': 0.547746380435263},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.155564984483274,
#   'seq_region_end': '185720635',
#   'seq_region_name': '4',
#   'seq_region_start': '185720635',
#   'snp': 'rs10017940',
#   'value': 0.698932146110815},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.936573478501953,
#   'seq_region_end': '185720889',
#   'seq_region_name': '4',
#   'seq_region_start': '185720889',
#   'snp': 'rs72702077',
#   'value': 0.115724822011919},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.151283446880001,
#   'seq_region_end': '185721052',
#   'seq_region_name': '4',
#   'seq_region_start': '185721052',
#   'snp': 'rs2047499',
#   'value': 0.705856719052914},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.197400703490479,
#   'seq_region_end': '185721168',
#   'seq_region_name': '4',
#   'seq_region_start': '185721168',
#   'snp': 'rs4861676',
#   'value': 0.634745011642261},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.0972546803760646,
#   'seq_region_end': '185721231',
#   'seq_region_name': '4',
#   'seq_region_start': '185721231',
#   'snp': 'rs4861677',
#   'value': 0.799365351115327},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.143044799790096,
#   'seq_region_end': '185721248',
#   'seq_region_name': '4',
#   'seq_region_start': '185721248',
#   'snp': 'rs4861678',
#   'value': 0.719374766835491},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.198229965017817,
#   'seq_region_end': '185721276',
#   'seq_region_name': '4',
#   'seq_region_start': '185721276',
#   'snp': 'rs4861679',
#   'value': 0.633534157204865},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.30269104238419,
#   'seq_region_end': '185721308',
#   'seq_region_name': '4',
#   'seq_region_start': '185721308',
#   'snp': 'rs4862567',
#   'value': 0.498091301718907},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.311201525875729,
#   'seq_region_end': '185721415',
#   'seq_region_name': '4',
#   'seq_region_start': '185721415',
#   'snp': 'rs77524200',
#   'value': 0.488425662356514},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.31765339554597,
#   'seq_region_end': '185721494',
#   'seq_region_name': '4',
#   'seq_region_start': '185721494',
#   'snp': 'rs13119888',
#   'value': 0.481223252895764},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.291370347610738,
#   'seq_region_end': '185721741',
#   'seq_region_name': '4',
#   'seq_region_start': '185721741',
#   'snp': 'rs11736488',
#   'value': 0.511245681323921},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.264551762343453,
#   'seq_region_end': '185722493',
#   'seq_region_name': '4',
#   'seq_region_start': '185722493',
#   'snp': 'rs4862568',
#   'value': 0.543811312509783},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.343815476025493,
#   'seq_region_end': '185722718',
#   'seq_region_name': '4',
#   'seq_region_start': '185722718',
#   'snp': 'rs77076502',
#   'value': 0.453090048887881},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.399113131499479,
#   'seq_region_end': '185722968',
#   'seq_region_name': '4',
#   'seq_region_start': '185722968',
#   'snp': 'rs11132341',
#   'value': 0.398920971945668},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.271757112667272,
#   'seq_region_end': '185723453',
#   'seq_region_name': '4',
#   'seq_region_start': '185723453',
#   'snp': 'rs6821153',
#   'value': 0.534863408155428},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 1.26915466407185,
#   'seq_region_end': '185723787',
#   'seq_region_name': '4',
#   'seq_region_start': '185723787',
#   'snp': 'rs113976592',
#   'value': 0.053807812414259},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.459632282125959,
#   'seq_region_end': '185723886',
#   'seq_region_name': '4',
#   'seq_region_start': '185723886',
#   'snp': 'rs74984681',
#   'value': 0.347030557455158},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.938410635370819,
#   'seq_region_end': '185724353',
#   'seq_region_name': '4',
#   'seq_region_start': '185724353',
#   'snp': 'rs72702080',
#   'value': 0.115236315680971},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.938410635370819,
#   'seq_region_end': '185724612',
#   'seq_region_name': '4',
#   'seq_region_start': '185724612',
#   'snp': 'rs72702082',
#   'value': 0.115236315680971},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.599021153299588,
#   'seq_region_end': '185725043',
#   'seq_region_name': '4',
#   'seq_region_start': '185725043',
#   'snp': 'rs62334814',
#   'value': 0.251755430156959},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.29062730570089,
#   'seq_region_end': '185725096',
#   'seq_region_name': '4',
#   'seq_region_start': '185725096',
#   'snp': 'rs76796229',
#   'value': 0.512121129062102},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.367793704093143,
#   'seq_region_end': '185725671',
#   'seq_region_name': '4',
#   'seq_region_start': '185725671',
#   'snp': 'rs6552917',
#   'value': 0.42875213524894},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.356099577530041,
#   'seq_region_end': '185726418',
#   'seq_region_name': '4',
#   'seq_region_start': '185726418',
#   'snp': 'rs11132342',
#   'value': 0.440453862139836},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.170838646519149,
#   'seq_region_end': '185727410',
#   'seq_region_name': '4',
#   'seq_region_start': '185727410',
#   'snp': 'rs4862569',
#   'value': 0.674778681736679},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.772644395459122,
#   'seq_region_end': '185727492',
#   'seq_region_name': '4',
#   'seq_region_start': '185727492',
#   'snp': 'rs10011292',
#   'value': 0.168793455691903},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.0689518222663582,
#   'seq_region_end': '185728641',
#   'seq_region_name': '4',
#   'seq_region_start': '185728641',
#   'snp': 'rs10014865',
#   'value': 0.853194756504574},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.45407315427497,
#   'seq_region_end': '185728674',
#   'seq_region_name': '4',
#   'seq_region_start': '185728674',
#   'snp': 'rs75770750',
#   'value': 0.351501227288676},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.429068866794924,
#   'seq_region_end': '185728977',
#   'seq_region_name': '4',
#   'seq_region_start': '185728977',
#   'snp': 'rs10014995',
#   'value': 0.372332660166894},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.2305707308072,
#   'seq_region_end': '185729281',
#   'seq_region_name': '4',
#   'seq_region_start': '185729281',
#   'snp': 'rs11730508',
#   'value': 0.588070331032145},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.137861077056439,
#   'seq_region_end': '185729534',
#   'seq_region_name': '4',
#   'seq_region_start': '185729534',
#   'snp': 'rs7691312',
#   'value': 0.728012645361491},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.94113779170913,
#   'seq_region_end': '185729781',
#   'seq_region_name': '4',
#   'seq_region_start': '185729781',
#   'snp': 'rs72702088',
#   'value': 0.114514955403124},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.291370347610738,
#   'seq_region_end': '185729792',
#   'seq_region_name': '4',
#   'seq_region_start': '185729792',
#   'snp': 'rs12650192',
#   'value': 0.511245681323921},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 1.1819354592804,
#   'seq_region_end': '185729830',
#   'seq_region_name': '4',
#   'seq_region_start': '185729830',
#   'snp': 'rs72702089',
#   'value': 0.0657755579477266},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.932816635174332,
#   'seq_region_end': '185730107',
#   'seq_region_name': '4',
#   'seq_region_start': '185730107',
#   'snp': 'rs10018379',
#   'value': 0.116730236339768},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.152678161485496,
#   'seq_region_end': '185730240',
#   'seq_region_name': '4',
#   'seq_region_start': '185730240',
#   'snp': 'rs6827602',
#   'value': 0.703593532156117},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.0575858977674221,
#   'seq_region_end': '185730267',
#   'seq_region_name': '4',
#   'seq_region_start': '185730267',
#   'snp': 'rs6850326',
#   'value': 0.875818475063525},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.176351307019692,
#   'seq_region_end': '185730284',
#   'seq_region_name': '4',
#   'seq_region_start': '185730285',
#   'snp': 'rs112523492',
#   'value': 0.666267597779407},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.155494375376121,
#   'seq_region_end': '185730292',
#   'seq_region_name': '4',
#   'seq_region_start': '185730293',
#   'snp': 'rs202098461',
#   'value': 0.699045790167781},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.607904179546794,
#   'seq_region_end': '185730677',
#   'seq_region_name': '4',
#   'seq_region_start': '185730677',
#   'snp': 'rs71624716',
#   'value': 0.246658349122742},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.351923057190281,
#   'seq_region_end': '185730693',
#   'seq_region_name': '4',
#   'seq_region_start': '185730693',
#   'snp': 'rs6856059',
#   'value': 0.444710048598423},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.298469492623471,
#   'seq_region_end': '185730726',
#   'seq_region_name': '4',
#   'seq_region_start': '185730726',
#   'snp': 'rs56054115',
#   'value': 0.502956595213258},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.601131986600642,
#   'seq_region_end': '185730738',
#   'seq_region_name': '4',
#   'seq_region_start': '185730738',
#   'snp': 'rs72702092',
#   'value': 0.250534773614123},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.271878375393158,
#   'seq_region_end': '185731138',
#   'seq_region_name': '4',
#   'seq_region_start': '185731138',
#   'snp': 'rs3796644',
#   'value': 0.534714085648458},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.629513462607387,
#   'seq_region_end': '185731316',
#   'seq_region_name': '4',
#   'seq_region_start': '185731316',
#   'snp': 'rs72702095',
#   'value': 0.234685651182539},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.446895322094467,
#   'seq_region_end': '185731551',
#   'seq_region_name': '4',
#   'seq_region_start': '185731551',
#   'snp': 'rs28432799',
#   'value': 0.35735896192602},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.217602277004243,
#   'seq_region_end': '185731691',
#   'seq_region_name': '4',
#   'seq_region_start': '185731691',
#   'snp': 'rs190417406',
#   'value': 0.605895494422968},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.0295609443195929,
#   'seq_region_end': '185731769',
#   'seq_region_name': '4',
#   'seq_region_start': '185731769',
#   'snp': 'rs11943390',
#   'value': 0.934198263500385},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.67335854543858,
#   'seq_region_end': '185731770',
#   'seq_region_name': '4',
#   'seq_region_start': '185731770',
#   'snp': 'rs115785898',
#   'value': 0.212149227428918},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.192564780464415,
#   'seq_region_end': '185731910',
#   'seq_region_name': '4',
#   'seq_region_start': '185731907',
#   'snp': 'rs199886377',
#   'value': 0.641852474027255},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.158446674504952,
#   'seq_region_end': '185731910',
#   'seq_region_name': '4',
#   'seq_region_start': '185731910',
#   'snp': 'rs28752036',
#   'value': 0.694309848349677},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.0549801720988489,
#   'seq_region_end': '185732924',
#   'seq_region_name': '4',
#   'seq_region_start': '185732924',
#   'snp': 'rs13135196',
#   'value': 0.881089098591075},
#  {'display_consequence': 'intron_variant',
#   'minus_log10_p_value': 0.539787631619634,
#   'seq_region_end': '185733223',
#   'seq_region_name': '4',
#   'seq_region_start': '185733223',
#   'snp': 'rs950590',
#   'value': 0.288544212863232}]

# %%
# getting list of specific values from the {tissue_gene_values_dict}
# collecting values and negative log10(p-value) for that gene

tissue_gene_values_dict[0]['minus_log10_p_value']
tissue_gene_values_dict[0]['value']

i = 0
minus_log10_p_value = []
value = []

for i in range(len(tissue_gene_values_dict)):
    minus_log10_p_value.append(tissue_gene_values_dict[i]['minus_log10_p_value'])
    value.append(tissue_gene_values_dict[i]['value'])

# %%
# because dictionary contains multiple location expression of the gene in chosen tissue,
# we collecting all values and converting it to mean

mean_minus_log10_p_value = np.mean(minus_log10_p_value)
mean_value = np.mean(value)

# %%
# making a list of chosen tissue for specific gene as [mean_minus_log10_p_value, mean_value]
tissue_gene_value = []

tissue_values.append(mean_minus_log10_p_value)
tissue_values.append(mean_value)
tissue_values

# for gene 'CENPU' in tissue 'Adipose_Visceral_Omentum' we get 
# [0.7590264183783493, 0.44036451350771805]
# [mean_minus_log10_p_value, mean_value]
# Out:
# [0.7590264183783493, 0.44036451350771805]

# %%
# attempt to iterrate through all tissues, with all genes, and create didctionary with values

server = "http://grch37.rest.ensembl.org"
statistic = 'p-value'
failed_genes = []
decoded_list = []

for t in tissue_list:
    tissue = t
    gene_values_gene = []
    
    for x in gene_name_list:
        gene = x
        
        ext = f"/eqtl/id/homo_sapiens/{gene}?;tissue={tissue};statistic={statistic}"
 
        r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
 
        if not r.ok:
            failed_genes.append(x)
            pass
 
        decoded = r.json()
        decoded_list.append(decoded)
        
        
#        minus_log10_p_value = []
#        value = []
#        
#        for i in range(len(decoded)):
#            minus_log10_p_value.append(decoded[i]['minus_log10_p_value'])
#            value.append(decoded[i]['value'])

#        mean_minus_log10_p_value = np.mean(minus_log10_p_value)
#        mean_value = np.mean(value)
        
#        gene_values_gene.append(mean_minus_log10_p_value)
#        gene_values_gene.append(mean_value)
        
        #gene_values_gene = dict([x, gene_values])
     
 #   gene_values_tissue.append()
    #epic_dict = dict([t, gene_dict])
        
#gene_tissue_df = pd.DataFrame(np.array([[gene_values]]), columns=tissue_list, index = gene_name_list)

# %%
    for x in gene_name_list:
        gene = x
        tissue = tissue_list[0]
        
        ext = f"/eqtl/id/homo_sapiens/{gene}?;tissue={tissue};statistic={statistic}"
 
        r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
 
        if not r.ok:
            failed_genes.append(x)
            pass
 
        decoded = r.json()
        
        
        minus_log10_p_value = []
        value = []
        
        for i in range(len(decoded)):
            minus_log10_p_value.append(decoded[i]['minus_log10_p_value'])
            value.append(decoded[i]['value'])
            
        mean_minus_log10_p_value = np.mean(minus_log10_p_value)
        mean_value = np.mean(value)
        
        gene_values_gene.append(mean_minus_log10_p_value)
        gene_values_gene.append(mean_value)

# %%
failed_genes = []
server = "http://grch37.rest.ensembl.org"
z = 189
a = 0
b = z
counter = 0

for x in gene_name_list[a:b]:
    gene = x
    tissue = tissue_list[0]
    #failed_genes = []
        
    ext = f"/eqtl/id/homo_sapiens/{gene}?;tissue={tissue};statistic={statistic}"
 
    r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
 
    if not r.ok:
        failed_genes.append(x)
        pass
    a = b
    b += z
    counter += 1
     
    #decoded = r.json()
    
print(failed_genes)
print(counter)
len(gene_name_list)/100
failed_genes = ['KDF1', 'NUP58', 'HIST1H2BM', 'LOC100134391', 'DDIAS', 'TCAF1', 'ADGRD2', 'RBM15B', 'LOC339862']
gene_name_list

# %%
#gene_name_list.remove('KDF1')
#gene_name_list.index("KDF1")
    
#gene_name_list.remove([y for y in failed_genes])
#gene_name_list = [x for x in gene_name_list if x != [y for y in failed_genes]]
len(gene_name_list) # 18989
#gene_name_list_cleaned = gene_name_list.remove([y for y in failed_genes])

# %%
len(gene_name_list)
def api_search ():
    server = "http://grch37.rest.ensembl.org"
    statistic = 'p-value'
    
    for t in tissue_list:
        tissue = t
    for x in gene_name_list:
        gene = x
        
decoded_list = []

# %%
# wrote possible function to create gene_values_gene 
def extracting_value(decoded):
    gene_values_gene = []
    for i in range(len(decoded)):
        minus_log10_p_value.append(decoded[i]['minus_log10_p_value'])
        value.append(decoded[i]['value'])
        
    mean_minus_log10_p_value = np.mean(minus_log10_p_value)
    mean_value = np.mean(value)
        
    gene_values_gene.append(mean_minus_log10_p_value)
    gene_values_gene.append(mean_value)
    
    return gene_values_gene

# %%
# small function that lest's you give it GENE SYMBOL and return enterz_id

def convert_symbol_to_entrezid(symbol):
    """Convert Symbol to Entrez Gene Id"""
    entrezdict = {}
    server = "http://rest.genenames.org/fetch/symbol/{0}".format(symbol)
    r = requests.get(server, headers={"Content-Type": "application/json"})
    if not r.ok:
        r.raise_for_status()
        sys.exit()
    response = r.text
    info = xmltodict.parse(response)
    for data in info['response']['result']['doc']['str']:
        if data['@name'] == 'entrez_id':
            entrezdict[data['@name']] = data['#text']
        if data['@name'] == 'symbol':
            entrezdict[data['@name']] = data['#text']
    return entrezdict

# %%
conversion = convert_symbol_to_entrezid(gene_name_list[0])
conversion['entrez_id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-7ce462fe134d> in <module>
# ----> 1 conversion = convert_symbol_to_entrezid(gene_name_list[0])
#       2 conversion['entrez_id']
#
# NameError: name 'gene_name_list' is not defined
